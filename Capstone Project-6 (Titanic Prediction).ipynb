# %% [markdown]
# # WELCOME!

# %% [markdown]
# **Overview**
#
# The data has been split into two groups:
#
# - training set (train.csv)
# - test set (test.csv)
#
# **The training set** should be used to build your machine learning models. For the training set, we provide the outcome (also known as the “ground truth”) for each passenger. Your model will be based on “features” like passengers’ gender and class. You can also use feature engineering to create new features.
#
# **The test set** should be used to see how well your model performs on unseen data. For the test set, we do not provide the ground truth for each passenger. It is your job to predict these outcomes. For each passenger in the test set, use the model you trained to predict whether or not they survived the sinking of the Titanic.
#
# We also include gender_submission.csv, a set of predictions that assume all and only female passengers survive, as an example of what a submission file should look like.
#
# **Data Dictionary**
#
# ![data%20dictionary.png](attachment:data%20dictionary.png)
#
# **Variable Notes**
#
# pclass: A proxy for socio-economic status (SES)
#
# 1st = Upper
#
# 2nd = Middle
#
# 3rd = Lower
#
# age: Age is fractional if less than 1. If the age is estimated, is it in the form of xx.5
#
# sibsp: The dataset defines family relations in this way...
#
# Sibling = brother, sister, stepbrother, stepsister
#
# Spouse = husband, wife (mistresses and fiancés were ignored)
#
# parch: The dataset defines family relations in this way...
#
# Parent = mother, father
#
# Child = daughter, son, stepdaughter, stepson
#
# Some children travelled only with a nanny, therefore parch=0 for them.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
plt.rcParams["figure.figsize"] = (9,5)
import warnings
warnings.filterwarnings('ignore')
pd.set_option('display.max_rows', 1000)
pd.set_option('display.max_columns', 1000)
pd.set_option('display.width', 1000)


from sklearn.preprocessing import OrdinalEncoder
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import accuracy_score,f1_score, classification_report,confusion_matrix
from sklearn.metrics import  recall_score, precision_score, roc_auc_score, auc
from sklearn.metrics import precision_recall_curve, plot_precision_recall_curve, plot_roc_curve
from sklearn.model_selection import train_test_split
from sklearn.model_selection import  GridSearchCV
from yellowbrick.classifier import ClassPredictionError, ROCAUC
from sklearn.pipeline  import Pipeline
from sklearn.ensemble import AdaBoostClassifier, GradientBoostingClassifier
from sklearn.model_selection import cross_val_score, cross_validate
from xgboost import XGBClassifier

# %% [markdown]
# # Exploratory Data Analysis and Visualization

# %%
train = pd.read_csv("train.csv")
test = pd.read_csv("test.csv")

# %%
print(train.shape)
train.head()
# Out:
# (891, 12)
#    PassengerId  Survived  Pclass                                               Name     Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# 0            1         0       3                            Braund, Mr. Owen Harris    male  22.0      1      0         A/5 21171   7.2500   NaN        S
# 1            2         1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1      0          PC 17599  71.2833   C85        C
# 2            3         1       3                             Heikkinen, Miss. Laina  female  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S
# 3            4         1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1      0            113803  53.1000  C123        S
# 4            5         0       3                           Allen, Mr. William Henry    male  35.0      0      0            373450   8.0500   NaN        S

# %%
print(test.shape)
test.head()
# Out:
# (418, 11)
#    PassengerId  Pclass                                          Name     Sex   Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0          892       3                              Kelly, Mr. James    male  34.5      0      0   330911   7.8292   NaN        Q
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0   363272   7.0000   NaN        S
# 2          894       2                     Myles, Mr. Thomas Francis    male  62.0      0      0   240276   9.6875   NaN        Q
# 3          895       3                              Wirz, Mr. Albert    male  27.0      0      0   315154   8.6625   NaN        S
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1  3101298  12.2875   NaN        S

# %%
total = train.shape[0] + test.shape[0]
test_perc = test.shape[0] / (train.shape[0] + test.shape[0])
print(" total number of data is ",total ,"\n",
      "test percentage is", round(test_perc*100,1) ,"\n", 
      "train percentage is",round((1 - test_perc)*100, 1))
# Out:
#  total number of data is  1309
#  test percentage is 31.9
#  train percentage is 68.1

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Pclass       418 non-null    int64
#  2   Name         418 non-null    object
#  3   Sex          418 non-null    object
#  4   Age          332 non-null    float64
#  5   SibSp        418 non-null    int64
#  6   Parch        418 non-null    int64
#  7   Ticket       418 non-null    object
#  8   Fare         417 non-null    float64
#  9   Cabin        91 non-null     object
#  10  Embarked     418 non-null    object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 36.0+ KB

# %%
test.isnull().sum()
# Out:
# PassengerId      0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %%
sns.heatmap(test.isnull(), yticklabels=False, cbar=False, cmap='viridis');

# %%
train.describe() # fare have outlier
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp       Parch        Fare
# count   891.000000  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std     257.353842    0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min       1.000000    0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
train.describe(include="object").T
# Out:
#          count unique                      top freq
# Name       891    891  Braund, Mr. Owen Harris    1
# Sex        891      2                     male  577
# Ticket     891    681                   347082    7
# Cabin      204    147                  B96 B98    4
# Embarked   889      3                        S  644

# %%
train.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
train.duplicated().sum()
# Out:
# 0

# %%
sns.heatmap(train.isnull(), yticklabels=False, cbar=False, cmap='viridis');

# %%
# id, ticket, cabin dropped
def dropping(data):
    data=data.drop(columns=['PassengerId', 'Ticket', 'Cabin'])
    data.Embarked.fillna('U', inplace=True)
    return data

# %%
train = dropping(train)
test = dropping(test)

# %%
sns.histplot(data=train, x='Age', kde=False, bins=30);

# %%
sns.histplot(x = "Age", hue= "Pclass", data = train, bins = 30);

# %%
train.groupby(['Pclass', 'Sex']).Age.median()
# aged people mostly have chosen Pclass 1
# younger ones have Pclass 3
# Out:
# Pclass  Sex
# 1       female    35.0
#         male      40.0
# 2       female    28.0
#         male      30.0
# 3       female    21.5
#         male      25.0
# Name: Age, dtype: float64

# %%
sns.boxplot(data=train, 
            x='Pclass', 
            y='Age', 
            showmeans=True,
            meanprops={"marker":"o",
                       "markerfacecolor":"white", 
                       "markeredgecolor":"black",
                       "markersize":"10"});

# %%
train["Age"].isnull().sum()
# Out:
# 177

# %%
print(train[(train['Age'].isnull()) & (train['Sex']=='female')]['Name'].to_markdown())

# for people who has null age to fill their age value we will average age of miss, mrs, or mr rows
# Out:
# |     | Name                                               |
# |----:|:---------------------------------------------------|
# |  19 | Masselmani, Mrs. Fatima                            |
# |  28 | O'Dwyer, Miss. Ellen "Nellie"                      |
# |  31 | Spencer, Mrs. William Augustus (Marie Eugenie)     |
# |  32 | Glynn, Miss. Mary Agatha                           |
# |  47 | O'Driscoll, Miss. Bridget                          |
# |  82 | McDermott, Miss. Brigdet Delia                     |
# | 109 | Moran, Miss. Bertha                                |
# | 128 | Peter, Miss. Anna                                  |
# | 140 | Boulos, Mrs. Joseph (Sultana)                      |
# | 166 | Chibnall, Mrs. (Edith Martha Bowerman)             |
# | 180 | Sage, Miss. Constance Gladys                       |
# | 186 | O'Brien, Mrs. Thomas (Johanna "Hannah" Godfrey)    |
# | 198 | Madigan, Miss. Margaret "Maggie"                   |
# | 229 | Lefebre, Miss. Mathilde                            |
# | 235 | Harknett, Miss. Alice Phoebe                       |
# | 240 | Zabour, Miss. Thamine                              |
# | 241 | Murphy, Miss. Katherine "Kate"                     |
# | 256 | Thorne, Mrs. Gertrude Maybelle                     |
# | 264 | Henry, Miss. Delia                                 |
# | 274 | Healy, Miss. Hanora "Nora"                         |
# | 300 | Kelly, Miss. Anna Katherine "Annie Kate"           |
# | 303 | Keane, Miss. Nora A                                |
# | 306 | Fleming, Miss. Margaret                            |
# | 330 | McCoy, Miss. Agnes                                 |
# | 334 | Frauenthal, Mrs. Henry William (Clara Heinsheimer) |
# | 347 | Davison, Mrs. Thomas Henry (Mary E Finck)          |
# | 358 | McGovern, Miss. Mary                               |
# | 359 | Mockler, Miss. Helen Mary "Ellie"                  |
# | 367 | Moussa, Mrs. (Mantoura Boulos)                     |
# | 368 | Jermyn, Miss. Annie                                |
# | 375 | Meyer, Mrs. Edgar Joseph (Leila Saks)              |
# | 409 | Lefebre, Miss. Ida                                 |
# | 415 | Meek, Mrs. Thomas (Annie Louise Rowley)            |
# | 431 | Thorneycroft, Mrs. Percival (Florence Kate White)  |
# | 457 | Kenyon, Mrs. Frederick R (Marion)                  |
# | 485 | Lefebre, Miss. Jeannie                             |
# | 502 | O'Sullivan, Miss. Bridget Mary                     |
# | 533 | Peter, Mrs. Catherine (Catherine Rizk)             |
# | 564 | Meanwell, Miss. (Marion Ogden)                     |
# | 573 | Kelly, Miss. Mary                                  |
# | 578 | Caram, Mrs. Joseph (Maria Elias)                   |
# | 593 | Bourke, Miss. Mary                                 |
# | 596 | Leitch, Miss. Jessie Wills                         |
# | 612 | Murphy, Miss. Margaret Jane                        |
# | 653 | O'Leary, Miss. Hanora "Norah"                      |
# | 669 | Taylor, Mrs. Elmer Zebley (Juliet Cummins Wright)  |
# | 680 | Peters, Miss. Katie                                |
# | 697 | Mullens, Miss. Katherine "Katie"                   |
# | 727 | Mannion, Miss. Margareth                           |
# | 792 | Sage, Miss. Stella Anna                            |
# | 849 | Goldenberg, Mrs. Samuel L (Edwiga Grabowska)       |
# | 863 | Sage, Miss. Dorothy Edith "Dolly"                  |
# | 888 | Johnston, Miss. Catherine Helen "Carrie"           |

# %%
def filling(data):
    data['Name']=data['Name'].apply(lambda x: 'Miss' if 'Miss.' in x else ('Mrs' if 'Mrs.' in x else 'Mr'))
    return data

# %%
filling(train)
filling(test)
# Out:
#      Pclass  Name     Sex    Age  SibSp  Parch      Fare Embarked
# 0         3    Mr    male  34.50      0      0    7.8292        Q
# 1         3   Mrs  female  47.00      1      0    7.0000        S
# 2         2    Mr    male  62.00      0      0    9.6875        Q
# 3         3    Mr    male  27.00      0      0    8.6625        S
# 4         3   Mrs  female  22.00      1      1   12.2875        S
# 5         3    Mr    male  14.00      0      0    9.2250        S
# 6         3  Miss  female  30.00      0      0    7.6292        Q
# 7         2    Mr    male  26.00      1      1   29.0000        S
# 8         3   Mrs  female  18.00      0      0    7.2292        C
# 9         3    Mr    male  21.00      2      0   24.1500        S
# 10        3    Mr    male    NaN      0      0    7.8958        S
# 11        1    Mr    male  46.00      0      0   26.0000        S
# 12        1   Mrs  female  23.00      1      0   82.2667        S
# 13        2    Mr    male  63.00      1      0   26.0000        S
# 14        1   Mrs  female  47.00      1      0   61.1750        S
# 15        2   Mrs  female  24.00      1      0   27.7208        C
# 16        2    Mr    male  35.00      0      0   12.3500        Q
# 17        3    Mr    male  21.00      0      0    7.2250        C
# 18        3  Miss  female  27.00      1      0    7.9250        S
# 19        3   Mrs  female  45.00      0      0    7.2250        C
# 20        1    Mr    male  55.00      1      0   59.4000        C
# 21        3    Mr    male   9.00      0      1    3.1708        S
# 22        1   Mrs  female    NaN      0      0   31.6833        S
# 23        1    Mr    male  21.00      0      1   61.3792        C
# 24        1   Mrs  female  48.00      1      3  262.3750        C
# 25        3    Mr    male  50.00      1      0   14.5000        S
# 26        1  Miss  female  22.00      0      1   61.9792        C
# 27        3    Mr    male  22.50      0      0    7.2250        C
# 28        1    Mr    male  41.00      0      0   30.5000        S
# 29        3    Mr    male    NaN      2      0   21.6792        C
# 30        2    Mr    male  50.00      1      0   26.0000        S
# 31        2    Mr    male  24.00      2      0   31.5000        S
# 32        3   Mrs  female  33.00      1      2   20.5750        S
# 33        3   Mrs  female    NaN      1      2   23.4500        S
# 34        1    Mr    male  30.00      1      0   57.7500        C
# 35        3    Mr    male  18.50      0      0    7.2292        C
# 36        3  Miss  female    NaN      0      0    8.0500        S
# 37        3  Miss  female  21.00      0      0    8.6625        S
# 38        3    Mr    male  25.00      0      0    9.5000        S
# 39        3    Mr    male    NaN      0      0   56.4958        S
# 40        3    Mr    male  39.00      0      1   13.4167        C
# 41        1    Mr    male    NaN      0      0   26.5500        S
# 42        3    Mr    male  41.00      0      0    7.8500        S
# 43        2   Mrs  female  30.00      0      0   13.0000        S
# 44        1   Mrs  female  45.00      1      0   52.5542        S
# 45        3    Mr    male  25.00      0      0    7.9250        S
# 46        1    Mr    male  45.00      0      0   29.7000        C
# 47        3    Mr    male    NaN      0      0    7.7500        Q
# 48        1   Mrs  female  60.00      0      0   76.2917        C
# 49        3   Mrs  female  36.00      0      2   15.9000        S
# 50        1    Mr    male  24.00      1      0   60.0000        S
# 51        2    Mr    male  27.00      0      0   15.0333        C
# 52        2  Miss  female  20.00      2      1   23.0000        S
# 53        1  Miss  female  28.00      3      2  263.0000        S
# 54        2    Mr    male    NaN      0      0   15.5792        C
# 55        3    Mr    male  10.00      4      1   29.1250        Q
# 56        3    Mr    male  35.00      0      0    7.8958        S
# 57        3    Mr    male  25.00      0      0    7.6500        S
# 58        3    Mr    male    NaN      1      0   16.1000        S
# 59        1  Miss  female  36.00      0      0  262.3750        C
# 60        3    Mr    male  17.00      0      0    7.8958        S
# 61        2    Mr    male  32.00      0      0   13.5000        S
# 62        3    Mr    male  18.00      0      0    7.7500        S
# 63        3  Miss  female  22.00      0      0    7.7250        Q
# 64        1    Mr    male  13.00      2      2  262.3750        C
# 65        2   Mrs  female    NaN      0      0   21.0000        S
# 66        3  Miss  female  18.00      0      0    7.8792        Q
# 67        1    Mr    male  47.00      0      0   42.4000        S
# 68        1    Mr    male  31.00      0      0   28.5375        C
# 69        1   Mrs  female  60.00      1      4  263.0000        S
# 70        3  Miss  female  24.00      0      0    7.7500        Q
# 71        3    Mr    male  21.00      0      0    7.8958        S
# 72        3  Miss  female  29.00      0      0    7.9250        S
# 73        1    Mr    male  28.50      0      0   27.7208        C
# 74        1  Miss  female  35.00      0      0  211.5000        C
# 75        1    Mr    male  32.50      0      0  211.5000        C
# 76        3    Mr    male    NaN      0      0    8.0500        S
# 77        1   Mrs  female  55.00      2      0   25.7000        S
# 78        2    Mr    male  30.00      0      0   13.0000        S
# 193       2    Mr    male  61.00      0      0   12.3500        Q
# 194       2    Mr    male   8.00      0      2   32.5000        S
# 195       3    Mr    male  33.00      0      0    7.8542        S
# 196       1    Mr    male   6.00      0      2  134.5000        C
# 197       3  Miss  female  18.00      0      0    7.7750        S
# 198       2    Mr    male  23.00      0      0   10.5000        S
# 199       3   Mrs  female    NaN      0      0    8.1125        S
# 200       3  Miss  female    NaN      0      0   15.5000        Q
# 201       3    Mr    male   0.33      0      2   14.4000        S
# 202       1    Mr    male  47.00      1      0  227.5250        C
# 203       2  Miss  female   8.00      1      1   26.0000        S
# 204       2    Mr    male  25.00      0      0   10.5000        S
# 205       1    Mr    male    NaN      0      0   25.7417        C
# 206       3  Miss  female  35.00      0      0    7.7500        Q
# 207       2    Mr    male  24.00      0      0   10.5000        S
# 208       1  Miss  female  33.00      0      0   27.7208        C
# 209       3    Mr    male  25.00      0      0    7.8958        S
# 210       3    Mr    male  32.00      0      0   22.5250        S
# 211       3    Mr    male    NaN      0      0    7.0500        S
# 212       2    Mr    male  17.00      0      0   73.5000        S
# 213       2   Mrs  female  60.00      1      0   26.0000        S
# 214       3  Miss  female  38.00      4      2    7.7750        S
# 215       1    Mr    male  42.00      0      0   42.5000        S
# 216       3  Miss  female    NaN      0      0    7.8792        Q
# 217       1    Mr    male  57.00      1      1  164.8667        S
# 218       1   Mrs  female  50.00      1      1  211.5000        C
# 219       3    Mr    male    NaN      0      0    8.0500        S
# 220       2  Miss  female  30.00      1      0   13.8583        C
# 221       3    Mr    male  21.00      0      0    8.0500        S
# 222       2   Mrs  female  22.00      0      0   10.5000        S
# 223       3    Mr    male  21.00      0      0    7.7958        S
# 224       1   Mrs  female  53.00      0      0   27.4458        C
# 225       3   Mrs  female    NaN      0      2   15.2458        C
# 226       3    Mr    male  23.00      0      0    7.7958        S
# 227       3  Miss  female    NaN      0      0    7.7500        Q
# 228       3    Mr    male  40.50      0      0   15.1000        S
# 229       2    Mr    male  36.00      0      0   13.0000        S
# 230       2    Mr    male  14.00      0      0   65.0000        S
# 231       1  Miss  female  21.00      0      0   26.5500        S
# 232       3    Mr    male  21.00      1      0    6.4958        S
# 233       3    Mr    male    NaN      0      0    7.8792        Q
# 234       1    Mr    male  39.00      1      0   71.2833        C
# 235       3    Mr    male  20.00      0      0    7.8542        S
# 236       1    Mr    male  64.00      1      0   75.2500        C
# 237       3    Mr    male  20.00      0      0    7.2250        C
# 238       2  Miss  female  18.00      1      1   13.0000        S
# 239       1   Mrs  female  48.00      1      0  106.4250        C
# 240       1   Mrs  female  55.00      0      0   27.7208        C
# 241       2   Mrs  female  45.00      0      2   30.0000        S
# 242       1    Mr    male  45.00      1      1  134.5000        C
# 243       3    Mr    male    NaN      0      0    7.8875        S
# 244       3    Mr    male    NaN      1      2   23.4500        S
# 245       1    Mr    male  41.00      1      0   51.8625        S
# 246       2   Mrs  female  22.00      0      0   21.0000        S
# 247       2    Mr    male  42.00      1      1   32.5000        S
# 248       2   Mrs  female  29.00      1      0   26.0000        S
# 249       3   Mrs  female    NaN      1      0   14.4542        C
# 250       2  Miss  female   0.92      1      2   27.7500        S
# 251       3    Mr    male  20.00      0      0    7.9250        S
# 252       1    Mr    male  27.00      1      0  136.7792        C
# 253       3    Mr    male  24.00      0      0    9.3250        S
# 254       3    Mr    male  32.50      0      0    9.5000        S
# 255       3    Mr    male    NaN      0      0    7.5500        S
# 256       3    Mr    male    NaN      0      0    7.7500        Q
# 257       3    Mr    male  28.00      0      0    8.0500        S
# 258       2  Miss  female  19.00      0      0   13.0000        S
# 259       3    Mr    male  21.00      0      0    7.7750        S
# 260       3    Mr    male  36.50      1      0   17.4000        S
# 261       3    Mr    male  21.00      0      0    7.8542        S
# 262       2   Mrs  female  29.00      0      2   23.0000        S
# 263       3  Miss  female   1.00      1      1   12.1833        S
# 264       2    Mr    male  30.00      0      0   12.7375        C
# 265       3    Mr    male    NaN      0      0    7.8958        S
# 266       1    Mr    male    NaN      0      0    0.0000        S
# 267       3    Mr    male    NaN      0      0    7.5500        S
# 268       3  Miss  female    NaN      0      0    8.0500        S
# 269       3    Mr    male  17.00      0      0    8.6625        S
# 270       1    Mr    male  46.00      0      0   75.2417        C
# 271       3    Mr    male    NaN      0      0    7.7500        Q
# 272       1   Mrs  female  26.00      1      0  136.7792        C
# 273       3  Miss  female    NaN      1      0   15.5000        Q
# 274       3    Mr    male    NaN      0      0    7.2250        C
# 275       2  Miss  female  20.00      1      0   26.0000        S
# 276       2    Mr    male  28.00      0      0   10.5000        S
# 277       2    Mr    male  40.00      1      0   26.0000        S
# 278       2    Mr    male  30.00      1      0   21.0000        S
# 279       2    Mr    male  22.00      0      0   10.5000        S
# 280       3  Miss  female  23.00      0      0    8.6625        S
# 281       3    Mr    male   0.75      1      1   13.7750        S
# 282       3  Miss  female    NaN      0      0    7.7500        Q
# 283       3  Miss  female   9.00      1      1   15.2458        C
# 284       3  Miss  female   2.00      1      1   20.2125        S
# 285       3    Mr    male  36.00      0      0    7.2500        S
# 286       3    Mr    male    NaN      0      0    7.2500        S
# 287       1    Mr    male  24.00      1      0   82.2667        S
# 288       3    Mr    male    NaN      0      0    7.2292        C
# 289       3    Mr    male    NaN      0      0    8.0500        S
# 290       1    Mr    male    NaN      0      0   39.6000        S
# 291       3  Miss  female  30.00      0      0    6.9500        Q
# 292       3    Mr    male    NaN      0      0    7.2292        C
# 293       1    Mr    male  53.00      1      1   81.8583        S
# 294       3    Mr    male  36.00      0      0    9.5000        S
# 295       3    Mr    male  26.00      0      0    7.8958        S
# 296       2  Miss  female   1.00      1      2   41.5792        C
# 297       3    Mr    male    NaN      2      0   21.6792        C
# 298       1    Mr    male  30.00      0      0   45.5000        S
# 299       3    Mr    male  29.00      0      0    7.8542        S
# 300       3    Mr    male  32.00      0      0    7.7750        S
# 301       2    Mr    male    NaN      0      0   15.0458        C
# 302       2    Mr    male  43.00      0      1   21.0000        S
# 303       3    Mr    male  24.00      0      0    8.6625        S
# 304       3  Miss  female    NaN      0      0    7.7500        Q
# 305       1   Mrs  female  64.00      1      1   26.5500        S
train.loc[train['Name']=='Mr']['Age'].mean()
# Out:
# 30.759065217391303

# %%
def filling2(data):
    a=['Miss', 'Mrs', 'Mr']
    b =[22, 36, 31]
    for i, k in zip(a,b):
        data.loc[data['Name']==i, 'Age'] = data.loc[data['Name']==i]['Age'].fillna(k)
    return data
        
filling2(train)
filling2(test)
# Out:
#      Pclass  Name     Sex    Age  SibSp  Parch      Fare Embarked
# 0         3    Mr    male  34.50      0      0    7.8292        Q
# 1         3   Mrs  female  47.00      1      0    7.0000        S
# 2         2    Mr    male  62.00      0      0    9.6875        Q
# 3         3    Mr    male  27.00      0      0    8.6625        S
# 4         3   Mrs  female  22.00      1      1   12.2875        S
# 5         3    Mr    male  14.00      0      0    9.2250        S
# 6         3  Miss  female  30.00      0      0    7.6292        Q
# 7         2    Mr    male  26.00      1      1   29.0000        S
# 8         3   Mrs  female  18.00      0      0    7.2292        C
# 9         3    Mr    male  21.00      2      0   24.1500        S
# 10        3    Mr    male  31.00      0      0    7.8958        S
# 11        1    Mr    male  46.00      0      0   26.0000        S
# 12        1   Mrs  female  23.00      1      0   82.2667        S
# 13        2    Mr    male  63.00      1      0   26.0000        S
# 14        1   Mrs  female  47.00      1      0   61.1750        S
# 15        2   Mrs  female  24.00      1      0   27.7208        C
# 16        2    Mr    male  35.00      0      0   12.3500        Q
# 17        3    Mr    male  21.00      0      0    7.2250        C
# 18        3  Miss  female  27.00      1      0    7.9250        S
# 19        3   Mrs  female  45.00      0      0    7.2250        C
# 20        1    Mr    male  55.00      1      0   59.4000        C
# 21        3    Mr    male   9.00      0      1    3.1708        S
# 22        1   Mrs  female  36.00      0      0   31.6833        S
# 23        1    Mr    male  21.00      0      1   61.3792        C
# 24        1   Mrs  female  48.00      1      3  262.3750        C
# 25        3    Mr    male  50.00      1      0   14.5000        S
# 26        1  Miss  female  22.00      0      1   61.9792        C
# 27        3    Mr    male  22.50      0      0    7.2250        C
# 28        1    Mr    male  41.00      0      0   30.5000        S
# 29        3    Mr    male  31.00      2      0   21.6792        C
# 30        2    Mr    male  50.00      1      0   26.0000        S
# 31        2    Mr    male  24.00      2      0   31.5000        S
# 32        3   Mrs  female  33.00      1      2   20.5750        S
# 33        3   Mrs  female  36.00      1      2   23.4500        S
# 34        1    Mr    male  30.00      1      0   57.7500        C
# 35        3    Mr    male  18.50      0      0    7.2292        C
# 36        3  Miss  female  22.00      0      0    8.0500        S
# 37        3  Miss  female  21.00      0      0    8.6625        S
# 38        3    Mr    male  25.00      0      0    9.5000        S
# 39        3    Mr    male  31.00      0      0   56.4958        S
# 40        3    Mr    male  39.00      0      1   13.4167        C
# 41        1    Mr    male  31.00      0      0   26.5500        S
# 42        3    Mr    male  41.00      0      0    7.8500        S
# 43        2   Mrs  female  30.00      0      0   13.0000        S
# 44        1   Mrs  female  45.00      1      0   52.5542        S
# 45        3    Mr    male  25.00      0      0    7.9250        S
# 46        1    Mr    male  45.00      0      0   29.7000        C
# 47        3    Mr    male  31.00      0      0    7.7500        Q
# 48        1   Mrs  female  60.00      0      0   76.2917        C
# 389       3    Mr    male   6.00      3      1   21.0750        S
# 390       1    Mr    male  23.00      0      0   93.5000        S
# 391       1   Mrs  female  51.00      0      1   39.4000        S
# 392       3    Mr    male  13.00      0      2   20.2500        S
# 393       2    Mr    male  47.00      0      0   10.5000        S
# 394       3    Mr    male  29.00      3      1   22.0250        S
# 395       1   Mrs  female  18.00      1      0   60.0000        S
# 396       3    Mr    male  24.00      0      0    7.2500        Q
# 397       1   Mrs  female  48.00      1      1   79.2000        C
# 398       3    Mr    male  22.00      0      0    7.7750        S
# 399       3    Mr    male  31.00      0      0    7.7333        Q
# 400       1  Miss  female  30.00      0      0  164.8667        S
# 401       2    Mr    male  38.00      1      0   21.0000        S
# 402       1  Miss  female  22.00      0      1   59.4000        C
# 403       1    Mr    male  17.00      0      0   47.1000        S
# 404       1    Mr    male  43.00      1      0   27.7208        C
# 405       2    Mr    male  20.00      0      0   13.8625        C
# 406       2    Mr    male  23.00      1      0   10.5000        S
# 407       1    Mr    male  50.00      1      1  211.5000        C
# 408       3  Miss  female  22.00      0      0    7.7208        Q
# 409       3  Miss  female   3.00      1      1   13.7750        S
# 410       3  Miss  female  22.00      0      0    7.7500        Q
# 411       1   Mrs  female  37.00      1      0   90.0000        Q
# 412       3  Miss  female  28.00      0      0    7.7750        S
# 413       3    Mr    male  31.00      0      0    8.0500        S
# 414       1    Mr  female  39.00      0      0  108.9000        C
# 415       3    Mr    male  38.50      0      0    7.2500        S
# 416       3    Mr    male  31.00      0      0    8.0500        S
# 417       3    Mr    male  31.00      1      1   22.3583        C

# %%
train.isnull().sum()
# Out:
# Survived    0
# Pclass      0
# Name        0
# Sex         0
# Age         0
# SibSp       0
# Parch       0
# Fare        0
# Embarked    0
# dtype: int64

# %%
test['Fare'] = test['Fare'].fillna(test['Fare'].mean())
test["Fare"]
# Out:
# 0        7.829200
# 1        7.000000
# 2        9.687500
# 3        8.662500
# 4       12.287500
# 5        9.225000
# 6        7.629200
# 7       29.000000
# 8        7.229200
# 9       24.150000
# 10       7.895800
# 11      26.000000
# 12      82.266700
# 13      26.000000
# 14      61.175000
# 15      27.720800
# 16      12.350000
# 17       7.225000
# 18       7.925000
# 19       7.225000
# 20      59.400000
# 21       3.170800
# 22      31.683300
# 23      61.379200
# 24     262.375000
# 25      14.500000
# 26      61.979200
# 27       7.225000
# 28      30.500000
# 29      21.679200
# 30      26.000000
# 31      31.500000
# 32      20.575000
# 33      23.450000
# 34      57.750000
# 35       7.229200
# 36       8.050000
# 37       8.662500
# 38       9.500000
# 39      56.495800
# 40      13.416700
# 41      26.550000
# 42       7.850000
# 43      13.000000
# 44      52.554200
# 45       7.925000
# 46      29.700000
# 47       7.750000
# 48      76.291700
# 49      15.900000
# 50      60.000000
# 51      15.033300
# 52      23.000000
# 53     263.000000
# 54      15.579200
# 55      29.125000
# 56       7.895800
# 57       7.650000
# 58      16.100000
# 59     262.375000
# 60       7.895800
# 61      13.500000
# 62       7.750000
# 63       7.725000
# 64     262.375000
# 65      21.000000
# 66       7.879200
# 67      42.400000
# 68      28.537500
# 69     263.000000
# 70       7.750000
# 71       7.895800
# 72       7.925000
# 73      27.720800
# 74     211.500000
# 75     211.500000
# 76       8.050000
# 77      25.700000
# 78      13.000000
# 79       7.750000
# 80      15.245800
# 81     221.779200
# 82      26.000000
# 83       7.895800
# 84      10.708300
# 85      14.454200
# 86       7.879200
# 87       8.050000
# 88       7.750000
# 89      23.000000
# 90      13.900000
# 91       7.775000
# 92      52.000000
# 93       8.050000
# 94      26.000000
# 95       7.795800
# 96      78.850000
# 97       7.925000
# 98       7.854200
# 99       8.050000
# 100     55.441700
# 101     26.000000
# 102      7.750000
# 103      7.775000
# 104      8.516700
# 105     22.525000
# 106      7.820800
# 107      7.750000
# 108      8.712500
# 109     13.000000
# 110     15.045800
# 111      7.779200
# 112     31.679200
# 113      7.283300
# 114    221.779200
# 115     14.454200
# 116      6.437500
# 117     16.700000
# 118     75.241700
# 119     26.000000
# 120     15.750000
# 121      7.750000
# 122     57.750000
# 123      7.250000
# 124      7.750000
# 125     16.100000
# 126      7.795800
# 127     23.250000
# 128     13.000000
# 129      8.050000
# 130      8.050000
# 131     28.500000
# 132     25.466700
# 133      6.437500
# 134      7.895800
# 135      7.854200
# 136      7.225000
# 137     13.000000
# 138      8.050000
# 139     46.900000
# 140     46.900000
# 141    151.550000
# 142    262.375000
# 143     26.000000
# 144     26.550000
# 145     18.000000
# 146     51.862500
# 147      8.050000
# 148     26.550000
# 149     26.000000
# 150     83.158300
# 151      7.895800
# 152     35.627188
# 153     12.183300
# 154     31.387500
# 155      7.550000
# 156    221.779200
# 157      7.854200
# 158     26.550000
# 159     13.775000
# 160      7.733300
# 161     15.245800
# 162     13.500000
# 163      7.000000
# 164     13.000000
# 165     22.025000
# 166     50.495800
# 167     34.375000
# 168     27.720800
# 169      8.962500
# 170      7.550000
# 171      7.225000
# 172     13.900000
# 173      7.229200
# 174     31.387500
# 175     39.000000
# 176     36.750000
# 177     55.441700
# 178     39.000000
# 179     83.158300
# 180     13.000000
# 181     83.158300
# 182     53.100000
# 183      7.750000
# 184    247.520800
# 185     16.000000
# 186     21.000000
# 187      8.050000
# 188     69.550000
# 189     13.000000
# 190     26.000000
# 191     26.000000
# 192     14.500000
# 193     12.350000
# 194     32.500000
# 195      7.854200
# 196    134.500000
# 197      7.775000
# 198     10.500000
# 199      8.112500
# 200     15.500000
# 201     14.400000
# 202    227.525000
# 203     26.000000
# 204     10.500000
# 205     25.741700
# 206      7.750000
# 207     10.500000
# 208     27.720800
# 209      7.895800
# 210     22.525000
# 211      7.050000
# 212     73.500000
# 213     26.000000
# 214      7.775000
# 215     42.500000
# 216      7.879200
# 217    164.866700
# 218    211.500000
# 219      8.050000
# 220     13.858300
# 221      8.050000
# 222     10.500000
# 223      7.795800
# 224     27.445800
# 225     15.245800
# 226      7.795800
# 227      7.750000
# 228     15.100000
# 229     13.000000
# 230     65.000000
# 231     26.550000
# 232      6.495800
# 233      7.879200
# 234     71.283300
# 235      7.854200
# 236     75.250000
# 237      7.225000
# 238     13.000000
# 239    106.425000
# 240     27.720800
# 241     30.000000
# 242    134.500000
# 243      7.887500
# 244     23.450000
# 245     51.862500
# 246     21.000000
# 247     32.500000
# 248     26.000000
# 249     14.454200
# 250     27.750000
# 251      7.925000
# 252    136.779200
# 253      9.325000
# 254      9.500000
# 255      7.550000
# 256      7.750000
# 257      8.050000
# 258     13.000000
# 259      7.775000
# 260     17.400000
# 261      7.854200
# 262     23.000000
# 263     12.183300
# 264     12.737500
# 265      7.895800
# 266      0.000000
# 267      7.550000
# 268      8.050000
# 269      8.662500
# 270     75.241700
# 271      7.750000
# 272    136.779200
# 273     15.500000
# 274      7.225000
# 275     26.000000
# 276     10.500000
# 277     26.000000
# 278     21.000000
# 279     10.500000
# 280      8.662500
# 281     13.775000
# 282      7.750000
# 283     15.245800
# 284     20.212500
# 285      7.250000
# 286      7.250000
# 287     82.266700
# 288      7.229200
# 289      8.050000
# 290     39.600000
# 291      6.950000
# 292      7.229200
# 293     81.858300
# 294      9.500000
# 295      7.895800
# 296     41.579200
# 297     21.679200
# 298     45.500000
# 299      7.854200
# 300      7.775000
# 301     15.045800
# 302     21.000000
# 303      8.662500
# 304      7.750000
# 305     26.550000
# 306    151.550000
# 307      9.350000
# 308     93.500000
# 309     14.108300
# 310      8.662500
# 311      7.225000
# 312      7.575000
# 313      7.750000
# 314    135.633300
# 315      7.733300
# 316    146.520800
# 317     10.500000
# 318      7.854200
# 319     31.500000
# 320      7.775000
# 321      7.229200
# 322     13.000000
# 323     26.550000
# 324    211.337500
# 325      7.050000
# 326     39.000000
# 327     79.200000
# 328     26.000000
# 329     13.000000
# 330     36.750000
# 331     29.700000
# 332      7.225000
# 333     15.741700
# 334      7.895800
# 335     26.000000
# 336     13.000000
# 337      7.229200
# 338     31.500000
# 339      7.229200
# 340     10.500000
# 341      7.579200
# 342     69.550000
# 343    512.329200
# 344     14.500000
# 345      7.650000
# 346     13.000000
# 347      7.229200
# 348     13.500000
# 349     21.000000
# 350     63.358300
# 351     10.500000
# 352     73.500000
# 353     65.000000
# 354     20.575000
# 355     26.000000
# 356     51.479200
# 357      7.879200
# 358      7.750000
# 359     15.550000
# 360     69.550000
# 361     37.004200
# 362     21.000000
# 363      8.662500
# 364     55.441700
# 365     69.550000
# 366     14.458300
# 367     39.687500
# 368     59.400000
# 369     13.858300
# 370     11.500000
# 371    134.500000
# 372      0.000000
# 373     13.000000
# 374     81.858300
# 375    262.375000
# 376      8.662500
# 377     11.500000
# 378     50.000000
# 379     31.387500
# 380      7.750000
# 381      7.879200
# 382     14.500000
# 383     16.100000
# 384     12.875000
# 385     65.000000
# 386      7.775000
# 387     13.000000
# 388      7.750000
# 389     21.075000
# 390     93.500000
# 391     39.400000
# 392     20.250000
# 393     10.500000
# 394     22.025000
# 395     60.000000
# 396      7.250000
# 397     79.200000
# 398      7.775000
# 399      7.733300
# 400    164.866700
# 401     21.000000
# 402     59.400000
# 403     47.100000
# 404     27.720800
# 405     13.862500
# 406     10.500000
# 407    211.500000
# 408      7.720800
# 409     13.775000
# 410      7.750000
# 411     90.000000
# 412      7.775000
# 413      8.050000
# 414    108.900000
# 415      7.250000
# 416      8.050000
# 417     22.358300
# Name: Fare, dtype: float64

# %%
test.isnull().sum()
# Out:
# Pclass      0
# Name        0
# Sex         0
# Age         0
# SibSp       0
# Parch       0
# Fare        0
# Embarked    0
# dtype: int64

# %%
train.drop(columns='Name', inplace=True)
test.drop(columns='Name', inplace=True)

# %%
train.head()
# Out:
#    Survived  Pclass     Sex   Age  SibSp  Parch     Fare Embarked
# 0         0       3    male  22.0      1      0   7.2500        S
# 1         1       1  female  38.0      1      0  71.2833        C
# 2         1       3  female  26.0      0      0   7.9250        S
# 3         1       1  female  35.0      1      0  53.1000        S
# 4         0       3    male  35.0      0      0   8.0500        S

# %%
test.head()
# Out:
#    Pclass     Sex   Age  SibSp  Parch     Fare Embarked
# 0       3    male  34.5      0      0   7.8292        Q
# 1       3  female  47.0      1      0   7.0000        S
# 2       2    male  62.0      0      0   9.6875        Q
# 3       3    male  27.0      0      0   8.6625        S
# 4       3  female  22.0      1      1  12.2875        S

# %%
train.Survived.value_counts()
# Out:
# 0    549
# 1    342
# Name: Survived, dtype: int64

# %% [markdown]
# ## Encoding

# %%
cols=['Sex', 'Embarked']
enc1=OrdinalEncoder(categories=[['female', 'male']])
enc2=OrdinalEncoder(categories=[['S','C','Q','U']])
enc = [enc1, enc2]
for i, k in zip(cols, enc):
    train[i]=k.fit_transform(train[[i]])
    test[i]=k.transform(test[[i]])

# %%
train.head()
# Out:
#    Survived  Pclass  Sex   Age  SibSp  Parch     Fare  Embarked
# 0         0       3  1.0  22.0      1      0   7.2500       0.0
# 1         1       1  0.0  38.0      1      0  71.2833       1.0
# 2         1       3  0.0  26.0      0      0   7.9250       0.0
# 3         1       1  0.0  35.0      1      0  53.1000       0.0
# 4         0       3  1.0  35.0      0      0   8.0500       0.0

# %%
test.head()
# Out:
#    Pclass  Sex   Age  SibSp  Parch     Fare  Embarked
# 0       3  1.0  34.5      0      0   7.8292       2.0
# 1       3  0.0  47.0      1      0   7.0000       0.0
# 2       2  1.0  62.0      0      0   9.6875       2.0
# 3       3  1.0  27.0      0      0   8.6625       0.0
# 4       3  0.0  22.0      1      1  12.2875       0.0

# %% [markdown]
# # Train | Test Split

# %%
X = train.drop(columns='Survived')
y = train['Survived']

# %%
X_train, X_test, y_train, y_test=train_test_split(X, y, test_size=0.2, random_state=101)

# %% [markdown]
# # AdaBoosting Classifier

# %%
ada = AdaBoostClassifier(random_state=101)
ada.fit(X_train, y_train)
# Out:
# AdaBoostClassifier(random_state=101)

# %%
prediction=ada.predict(X_test)
accuracy_score(y_test, prediction)
# Out:
# 0.7932960893854749

# %% [markdown]
# ## Model Performance

# %%
def eval_metric(model, X_train, y_train, X_test, y_test):
    y_train_pred = model.predict(X_train)
    y_pred = model.predict(X_test)
    print("Test_Set")
    print(confusion_matrix(y_test, y_pred))
    print(classification_report(y_test, y_pred))
    print()
    print("Train_Set")
    print(confusion_matrix(y_train, y_train_pred))
    print(classification_report(y_train, y_train_pred))

# %%
eval_metric(ada, X_train, y_train, X_test, y_test)
# Out:
# Test_Set
# [[87 12]
#  [25 55]]
#               precision    recall  f1-score   support
#
#            0       0.78      0.88      0.82        99
#            1       0.82      0.69      0.75        80
#
#     accuracy                           0.79       179
#    macro avg       0.80      0.78      0.79       179
# weighted avg       0.80      0.79      0.79       179
#
#
# Train_Set
# [[404  46]
#  [ 68 194]]
#               precision    recall  f1-score   support
#
#            0       0.86      0.90      0.88       450
#            1       0.81      0.74      0.77       262
#
#     accuracy                           0.84       712
#    macro avg       0.83      0.82      0.82       712
# weighted avg       0.84      0.84      0.84       712

# %%
from sklearn.model_selection import cross_val_score, cross_validate
model = AdaBoostClassifier(n_estimators=50, random_state=101)
scores = cross_validate(model, X_train, y_train, scoring = ["accuracy", "precision", "recall", "f1"], cv = 10)
df_scores = pd.DataFrame(scores, index = range(1, 11))
df_scores.mean()[2:]
# Out:
# test_accuracy     0.800685
# test_precision    0.739712
# test_recall       0.714103
# test_f1           0.724560
# dtype: float64

# %% [markdown]
# # Analyze the performance

# %%
error_rates = []
for n in range(1,200):
    model = AdaBoostClassifier(n_estimators=n)
    model.fit(X_train,y_train)
    preds = model.predict(X_test)
    err = 1 - f1_score(y_test,preds)
    error_rates.append(err)

    
plt.plot(range(1,200), error_rates);

# %% [markdown]
# ## Ada - GridSearchCV

# %%
train["Survived"].value_counts()
# Out:
# 0    549
# 1    342
# Name: Survived, dtype: int64

# %%
param_grid = {"n_estimators": [10, 50, 100, 200, 300], "learning_rate": [0.01, 0.1, 0.2, 0.5, 1.0]}

ada_model = AdaBoostClassifier()
ada_grid = GridSearchCV(ada_model, param_grid, scoring = "accuracy", verbose=2, n_jobs = -1, 
                        return_train_score=True)
ada_grid.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 25 candidates, totalling 125 fits
# GridSearchCV(estimator=AdaBoostClassifier(), n_jobs=-1,
#              param_grid={'learning_rate': [0.01, 0.1, 0.2, 0.5, 1.0],
#                          'n_estimators': [10, 50, 100, 200, 300]},
#              return_train_score=True, scoring='accuracy', verbose=2)

# %%
ada_grid.best_params_
# Out:
# {'learning_rate': 0.2, 'n_estimators': 200}

# %%
ada_grid.best_score_
# Out:
# 0.8090219639515415

# %%
y_pred_test = ada_grid.predict(X_test)
y_pred_train = ada_grid.predict(X_train)

# %%
ada_accuracy_test = accuracy_score(y_test, y_pred_test)
ada_accuracy_train = accuracy_score(y_train, y_pred_train)

ada_f1_test = f1_score(y_test, y_pred_test)
ada_f1_train = f1_score(y_train, y_pred_train)

ada_accuracy_test, ada_accuracy_train, ada_f1_test, ada_f1_train
# Out:
# (0.7932960893854749,
#  0.8286516853932584,
#  0.7482993197278912,
#  0.7635658914728682)

# %%
y_pred = ada_grid.predict(X_test)
ada_f1 = f1_score(y_test, y_pred)
ada_recall = recall_score(y_test, y_pred)
ada_auc = roc_auc_score(y_test, y_pred)
eval_metric(ada_grid, X_train, y_train, X_test, y_test)
# Out:
# Test_Set
# [[87 12]
#  [25 55]]
#               precision    recall  f1-score   support
#
#            0       0.78      0.88      0.82        99
#            1       0.82      0.69      0.75        80
#
#     accuracy                           0.79       179
#    macro avg       0.80      0.78      0.79       179
# weighted avg       0.80      0.79      0.79       179
#
#
# Train_Set
# [[393  57]
#  [ 65 197]]
#               precision    recall  f1-score   support
#
#            0       0.86      0.87      0.87       450
#            1       0.78      0.75      0.76       262
#
#     accuracy                           0.83       712
#    macro avg       0.82      0.81      0.81       712
# weighted avg       0.83      0.83      0.83       712

# %% [markdown]
# # Prediction with Best Hyper Parameters

# %%
ada_test=AdaBoostClassifier(
 learning_rate= 0.2,
 n_estimators= 100)

ada_test.fit(X_train,y_train)
# Out:
# AdaBoostClassifier(learning_rate=0.2, n_estimators=100)

# %%
gender_submission = pd.read_csv("gender_submission.csv")
sub_pred1=ada_test.predict(test)
accuracy_score(gender_submission.Survived.values, sub_pred1)
# Out:
# 0.8492822966507177

# %% [markdown]
# # Feature Importances

# %%
model = AdaBoostClassifier(n_estimators=200, learning_rate=0.2, random_state=101)
model.fit(X_train, y_train)
model.feature_importances_

feats = pd.DataFrame(index=X.columns, data= model.feature_importances_, columns=['ada_importance'])
ada_imp_feats = feats.sort_values("ada_importance")
ada_imp_feats
# Out:
#           ada_importance
# Embarked           0.035
# Parch              0.040
# Pclass             0.055
# SibSp              0.085
# Sex                0.100
# Age                0.280
# Fare               0.405

# %%
plt.figure(figsize=(12,6))
sns.barplot(data=ada_imp_feats ,x=ada_imp_feats.index, y='ada_importance')

plt.xticks(rotation=90);

# %% [markdown]
# # Evaluating ROC Curves, Precision Recall Curve

# %%
y_pred_test = ada_grid.predict(X_test)
y_pred_train = ada_grid.predict(X_train)

# %%
plot_roc_curve(ada_grid, X_test, y_test);

# %%
ada_auc = roc_auc_score(y_test, y_pred_test)
ada_auc
# Out:
# 0.7831439393939393

# %%
plot_precision_recall_curve(ada_grid, X_test, y_test);

# %%
y_pred_proba = ada_grid.predict_proba(X_test)[:, 1]

precision, recall, threshold = precision_recall_curve(y_test, y_pred_proba)

ada_prc = auc(recall, precision)
ada_prc
# Out:
# 0.8754786801449447

# %% [markdown]
# # GradientBoosting Classifier

# %%
grb = GradientBoostingClassifier(random_state=101)
grb.fit(X_train, y_train)
# Out:
# GradientBoostingClassifier(random_state=101)

# %%
param_grid = {"n_estimators":[100, 200], "subsample":[0.5, 1], "max_features" : [None, 2, 3], "learning_rate": [0.001, 0.01], 'max_depth':[3,4,5]}

grb_model = GradientBoostingClassifier()
grb_grid = GridSearchCV(grb_model, param_grid, scoring = "accuracy", verbose=2, n_jobs = -1, 
                        return_train_score=True)
grb_grid.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 72 candidates, totalling 360 fits
# GridSearchCV(estimator=GradientBoostingClassifier(), n_jobs=-1,
#              param_grid={'learning_rate': [0.001, 0.01], 'max_depth': [3, 4, 5],
#                          'max_features': [None, 2, 3],
#                          'n_estimators': [100, 200], 'subsample': [0.5, 1]},
#              return_train_score=True, scoring='accuracy', verbose=2)

# %%
grb_grid.best_params_
# Out:
# {'learning_rate': 0.01,
#  'max_depth': 5,
#  'max_features': 3,
#  'n_estimators': 100,
#  'subsample': 1}

# %%
grb_grid.best_score_
# Out:
# 0.8314685314685315

# %%
y_pred_test = grb_grid.predict(X_test)
y_pred_train = grb_grid.predict(X_train)

# %%
grb_accuracy_test = accuracy_score(y_test, y_pred_test)
grb_accuracy_train = accuracy_score(y_train, y_pred_train)

grb_f1_test = f1_score(y_test, y_pred_test)
grb_f1_train = f1_score(y_train, y_pred_train)

grb_accuracy_test, grb_accuracy_train, grb_f1_test, grb_f1_train
# Out:
# (0.8044692737430168,
#  0.8567415730337079,
#  0.7244094488188976,
#  0.7702702702702702)

# %%
y_pred = grb_grid.predict(X_test)
grb_f1 = f1_score(y_test, y_pred)
grb_recall = recall_score(y_test, y_pred)
grb_auc = roc_auc_score(y_test, y_pred)
eval_metric(grb_grid, X_train, y_train, X_test, y_test)
# Out:
# Test_Set
# [[98  1]
#  [34 46]]
#               precision    recall  f1-score   support
#
#            0       0.74      0.99      0.85        99
#            1       0.98      0.57      0.72        80
#
#     accuracy                           0.80       179
#    macro avg       0.86      0.78      0.79       179
# weighted avg       0.85      0.80      0.79       179
#
#
# Train_Set
# [[439  11]
#  [ 91 171]]
#               precision    recall  f1-score   support
#
#            0       0.83      0.98      0.90       450
#            1       0.94      0.65      0.77       262
#
#     accuracy                           0.86       712
#    macro avg       0.88      0.81      0.83       712
# weighted avg       0.87      0.86      0.85       712

# %% [markdown]
# # Prediction with Hyper Parameters

# %%
grb_f=GradientBoostingClassifier(
 learning_rate= 0.01,
 max_depth= 4,
 n_estimators= 100,
 max_features= 2,
 subsample= 1)
grb_f.fit(X_train,y_train)
# Out:
# GradientBoostingClassifier(learning_rate=0.01, max_depth=4, max_features=2,
#                            subsample=1)

# %%
sub_pred2=grb_f.predict(test)
accuracy_score(gender_submission.Survived.values, sub_pred2)
# Out:
# 0.8660287081339713

# %% [markdown]
# # Feature Importances

# %%
model = GradientBoostingClassifier(
 learning_rate= 0.01,
 max_depth= 4,
 n_estimators= 100,
 max_features= 2,
 subsample= 1,
 random_state=101)

model.fit(X_train, y_train)

model.feature_importances_

feats = pd.DataFrame(index=X.columns, data=model.feature_importances_, columns=['grad_importance'])
grad_imp_feats = feats.sort_values("grad_importance")
grad_imp_feats
# Out:
#           grad_importance
# Embarked         0.023792
# Parch            0.026482
# SibSp            0.042335
# Age              0.105593
# Fare             0.134197
# Pclass           0.165611
# Sex              0.501990

# %%
plt.figure(figsize=(12,6))
sns.barplot(data=grad_imp_feats, x=grad_imp_feats.index, y='grad_importance')

plt.xticks(rotation=90);

# %% [markdown]
# # Evaluating ROC Curves and AUC

# %%
plot_roc_curve(grb_grid, X_test, y_test);

# %%
grb_auc = roc_auc_score(y_test, y_pred_test)
grb_auc
# Out:
# 0.7824494949494949

# %%
plot_precision_recall_curve(grb_grid, X_test, y_test);

# %%
y_pred_proba = grb_grid.predict_proba(X_test)[:, 1]

precision, recall, threshold = precision_recall_curve(y_test, y_pred_proba)

grb_prc = auc(recall, precision)
grb_prc
# Out:
# 0.8976611375511658

# %% [markdown]
# # XGBoosting Classifier

# %%
xgb = XGBClassifier(random_state=101)
xgb.fit(X_train, y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               n_estimators=100, n_jobs=None, num_parallel_tree=None,
#               predictor=None, random_state=101, ...)
# [CV] END learning_rate=0.001, max_depth=3, max_features=None, n_estimators=100, subsample=1; total time=   0.1s
# [CV] END learning_rate=0.001, max_depth=3, max_features=None, n_estimators=200, subsample=0.5; total time=   0.2s
# [CV] END learning_rate=0.001, max_depth=3, max_features=None, n_estimators=200, subsample=1; total time=   0.2s
# [CV] END learning_rate=0.001, max_depth=3, max_features=2, n_estimators=200, subsample=0.5; total time=   0.1s
# [CV] END learning_rate=0.001, max_depth=3, max_features=2, n_estimators=200, subsample=1; total time=   0.1s
# [CV] END learning_rate=0.001, max_depth=3, max_features=3, n_estimators=200, subsample=0.5; total time=   0.2s
# [CV] END learning_rate=0.001, max_depth=4, max_features=None, n_estimators=100, subsample=0.5; total time=   0.1s
# [CV] END learning_rate=0.001, max_depth=4, max_features=None, n_estimators=100, subsample=1; total time=   0.1s
# [CV] END learning_rate=0.001, max_depth=4, max_features=None, n_estimators=200, subsample=1; total time=   0.2s
# [CV] END learning_rate=0.001, max_depth=4, max_features=2, n_estimators=100, subsample=0.5; total time=   0.1s
# [CV] END learning_rate=0.001, max_depth=4, max_features=2, n_estimators=200, subsample=0.5; total time=   0.2s
# [CV] END learning_rate=0.001, max_depth=4, max_features=2, n_estimators=200, subsample=1; total time=   0.2s
# [CV] END learning_rate=0.001, max_depth=4, max_features=3, n_estimators=200, subsample=0.5; total time=   0.2s
# [CV] END learning_rate=0.001, max_depth=5, max_features=None, n_estimators=100, subsample=0.5; total time=   0.2s
# [CV] END learning_rate=0.001, max_depth=5, max_features=None, n_estimators=100, subsample=1; total time=   0.2s
# [CV] END learning_rate=0.001, max_depth=5, max_features=None, n_estimators=200, subsample=1; total time=   0.3s
# [CV] END learning_rate=0.001, max_depth=5, max_features=2, n_estimators=100, subsample=1; total time=   0.1s
# [CV] END learning_rate=0.001, max_depth=5, max_features=2, n_estimators=200, subsample=0.5; total time=   0.3s
# [CV] END learning_rate=0.001, max_depth=5, max_features=2, n_estimators=200, subsample=1; total time=   0.2s
# [CV] END learning_rate=0.001, max_depth=5, max_features=3, n_estimators=200, subsample=0.5; total time=   0.3s
# [CV] END learning_rate=0.01, max_depth=3, max_features=None, n_estimators=100, subsample=0.5; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=3, max_features=None, n_estimators=100, subsample=1; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=3, max_features=None, n_estimators=200, subsample=0.5; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=3, max_features=None, n_estimators=200, subsample=1; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=3, max_features=2, n_estimators=200, subsample=0.5; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=3, max_features=3, n_estimators=100, subsample=0.5; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=3, max_features=3, n_estimators=100, subsample=1; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=3, max_features=3, n_estimators=200, subsample=1; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=4, max_features=None, n_estimators=100, subsample=1; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=4, max_features=None, n_estimators=200, subsample=0.5; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=4, max_features=2, n_estimators=100, subsample=0.5; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=4, max_features=2, n_estimators=100, subsample=1; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=4, max_features=2, n_estimators=200, subsample=0.5; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=4, max_features=2, n_estimators=200, subsample=1; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=4, max_features=3, n_estimators=200, subsample=0.5; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=4, max_features=3, n_estimators=200, subsample=1; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=5, max_features=None, n_estimators=100, subsample=1; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=5, max_features=None, n_estimators=200, subsample=1; total time=   0.3s
# [CV] END learning_rate=0.01, max_depth=5, max_features=2, n_estimators=100, subsample=0.5; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=5, max_features=2, n_estimators=200, subsample=0.5; total time=   0.3s
# [CV] END learning_rate=0.01, max_depth=5, max_features=2, n_estimators=200, subsample=1; total time=   0.3s
# [CV] END learning_rate=0.01, max_depth=5, max_features=3, n_estimators=200, subsample=0.5; total time=   0.3s
# [CV] END learning_rate=0.001, max_depth=3, max_features=None, n_estimators=100, subsample=0.5; total time=   0.1s
# [CV] END learning_rate=0.001, max_depth=3, max_features=None, n_estimators=200, subsample=0.5; total time=   0.2s
# [CV] END learning_rate=0.001, max_depth=3, max_features=None, n_estimators=200, subsample=1; total time=   0.2s
# [CV] END learning_rate=0.001, max_depth=3, max_features=2, n_estimators=200, subsample=1; total time=   0.1s
# [CV] END learning_rate=0.001, max_depth=3, max_features=3, n_estimators=100, subsample=0.5; total time=   0.1s
# [CV] END learning_rate=0.001, max_depth=3, max_features=3, n_estimators=100, subsample=1; total time=   0.1s
# [CV] END learning_rate=0.001, max_depth=3, max_features=3, n_estimators=200, subsample=0.5; total time=   0.1s
# [CV] END learning_rate=0.001, max_depth=4, max_features=None, n_estimators=100, subsample=0.5; total time=   0.1s
# [CV] END learning_rate=0.001, max_depth=4, max_features=None, n_estimators=100, subsample=1; total time=   0.1s
# [CV] END learning_rate=0.001, max_depth=4, max_features=None, n_estimators=200, subsample=1; total time=   0.3s
# [CV] END learning_rate=0.001, max_depth=4, max_features=2, n_estimators=100, subsample=1; total time=   0.1s
# [CV] END learning_rate=0.001, max_depth=4, max_features=2, n_estimators=200, subsample=1; total time=   0.2s
# [CV] END learning_rate=0.001, max_depth=4, max_features=3, n_estimators=100, subsample=0.5; total time=   0.1s
# [CV] END learning_rate=0.001, max_depth=4, max_features=3, n_estimators=100, subsample=1; total time=   0.1s
# [CV] END learning_rate=0.001, max_depth=4, max_features=3, n_estimators=200, subsample=1; total time=   0.2s
# [CV] END learning_rate=0.001, max_depth=5, max_features=None, n_estimators=100, subsample=0.5; total time=   0.1s
# [CV] END learning_rate=0.001, max_depth=5, max_features=None, n_estimators=200, subsample=0.5; total time=   0.3s
# [CV] END learning_rate=0.001, max_depth=5, max_features=None, n_estimators=200, subsample=1; total time=   0.4s
# [CV] END learning_rate=0.001, max_depth=5, max_features=2, n_estimators=200, subsample=1; total time=   0.3s
# [CV] END learning_rate=0.001, max_depth=5, max_features=3, n_estimators=100, subsample=0.5; total time=   0.2s
# [CV] END learning_rate=0.001, max_depth=5, max_features=3, n_estimators=200, subsample=0.5; total time=   0.3s
# [CV] END learning_rate=0.001, max_depth=5, max_features=3, n_estimators=200, subsample=1; total time=   0.3s
# [CV] END learning_rate=0.01, max_depth=3, max_features=None, n_estimators=200, subsample=1; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=3, max_features=2, n_estimators=100, subsample=0.5; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=3, max_features=2, n_estimators=200, subsample=0.5; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=3, max_features=2, n_estimators=200, subsample=1; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=3, max_features=3, n_estimators=200, subsample=0.5; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=4, max_features=None, n_estimators=100, subsample=0.5; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=4, max_features=None, n_estimators=100, subsample=1; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=4, max_features=None, n_estimators=200, subsample=0.5; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=4, max_features=2, n_estimators=100, subsample=0.5; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=4, max_features=2, n_estimators=100, subsample=1; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=4, max_features=2, n_estimators=200, subsample=1; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=4, max_features=3, n_estimators=100, subsample=1; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=4, max_features=3, n_estimators=200, subsample=0.5; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=4, max_features=3, n_estimators=200, subsample=1; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=5, max_features=None, n_estimators=100, subsample=1; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=5, max_features=None, n_estimators=200, subsample=1; total time=   0.3s
# [CV] END learning_rate=0.01, max_depth=5, max_features=2, n_estimators=100, subsample=0.5; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=5, max_features=2, n_estimators=100, subsample=1; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=5, max_features=2, n_estimators=200, subsample=1; total time=   0.3s
# [CV] END learning_rate=0.01, max_depth=5, max_features=3, n_estimators=100, subsample=1; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=5, max_features=3, n_estimators=200, subsample=0.5; total time=   0.3s
# [CV] END learning_rate=0.001, max_depth=3, max_features=None, n_estimators=100, subsample=0.5; total time=   0.1s
# [CV] END learning_rate=0.001, max_depth=3, max_features=None, n_estimators=100, subsample=1; total time=   0.1s
# [CV] END learning_rate=0.001, max_depth=3, max_features=None, n_estimators=200, subsample=1; total time=   0.2s
# [CV] END learning_rate=0.001, max_depth=3, max_features=2, n_estimators=100, subsample=0.5; total time=   0.1s
# [CV] END learning_rate=0.001, max_depth=3, max_features=2, n_estimators=200, subsample=0.5; total time=   0.1s
# [CV] END learning_rate=0.001, max_depth=3, max_features=3, n_estimators=100, subsample=0.5; total time=   0.1s
# [CV] END learning_rate=0.001, max_depth=3, max_features=3, n_estimators=100, subsample=1; total time=   0.1s
# [CV] END learning_rate=0.001, max_depth=3, max_features=3, n_estimators=200, subsample=1; total time=   0.1s
# [CV] END learning_rate=0.001, max_depth=4, max_features=None, n_estimators=100, subsample=0.5; total time=   0.1s
# [CV] END learning_rate=0.001, max_depth=4, max_features=None, n_estimators=200, subsample=0.5; total time=   0.2s
# [CV] END learning_rate=0.001, max_depth=4, max_features=None, n_estimators=200, subsample=1; total time=   0.2s
# [CV] END learning_rate=0.001, max_depth=4, max_features=2, n_estimators=200, subsample=0.5; total time=   0.2s
# [CV] END learning_rate=0.001, max_depth=4, max_features=3, n_estimators=100, subsample=0.5; total time=   0.1s
# [CV] END learning_rate=0.001, max_depth=4, max_features=3, n_estimators=100, subsample=1; total time=   0.1s
# [CV] END learning_rate=0.001, max_depth=4, max_features=3, n_estimators=200, subsample=0.5; total time=   0.2s
# [CV] END learning_rate=0.001, max_depth=5, max_features=None, n_estimators=100, subsample=0.5; total time=   0.1s
# [CV] END learning_rate=0.001, max_depth=5, max_features=None, n_estimators=100, subsample=1; total time=   0.1s
# [CV] END learning_rate=0.001, max_depth=5, max_features=None, n_estimators=200, subsample=1; total time=   0.3s
# [CV] END learning_rate=0.001, max_depth=5, max_features=2, n_estimators=100, subsample=0.5; total time=   0.2s
# [CV] END learning_rate=0.001, max_depth=5, max_features=2, n_estimators=200, subsample=0.5; total time=   0.3s
# [CV] END learning_rate=0.001, max_depth=5, max_features=3, n_estimators=100, subsample=0.5; total time=   0.1s
# [CV] END learning_rate=0.001, max_depth=5, max_features=3, n_estimators=100, subsample=1; total time=   0.1s
# [CV] END learning_rate=0.001, max_depth=5, max_features=3, n_estimators=200, subsample=1; total time=   0.3s
# [CV] END learning_rate=0.01, max_depth=3, max_features=None, n_estimators=100, subsample=0.5; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=3, max_features=None, n_estimators=200, subsample=0.5; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=3, max_features=None, n_estimators=200, subsample=1; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=3, max_features=2, n_estimators=200, subsample=1; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=3, max_features=3, n_estimators=100, subsample=0.5; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=3, max_features=3, n_estimators=100, subsample=1; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=3, max_features=3, n_estimators=200, subsample=0.5; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=4, max_features=None, n_estimators=100, subsample=0.5; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=4, max_features=None, n_estimators=100, subsample=1; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=4, max_features=None, n_estimators=200, subsample=1; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=4, max_features=2, n_estimators=100, subsample=1; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=4, max_features=2, n_estimators=200, subsample=1; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=4, max_features=3, n_estimators=100, subsample=0.5; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=4, max_features=3, n_estimators=100, subsample=1; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=4, max_features=3, n_estimators=200, subsample=1; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=5, max_features=None, n_estimators=100, subsample=0.5; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=5, max_features=None, n_estimators=100, subsample=1; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=5, max_features=None, n_estimators=200, subsample=1; total time=   0.3s
# [CV] END learning_rate=0.01, max_depth=5, max_features=2, n_estimators=100, subsample=1; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=5, max_features=2, n_estimators=200, subsample=0.5; total time=   0.3s
# [CV] END learning_rate=0.01, max_depth=5, max_features=3, n_estimators=100, subsample=0.5; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=5, max_features=3, n_estimators=100, subsample=1; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=5, max_features=3, n_estimators=200, subsample=0.5; total time=   0.3s
# [CV] END learning_rate=0.001, max_depth=3, max_features=None, n_estimators=100, subsample=0.5; total time=   0.1s
# [CV] END learning_rate=0.001, max_depth=3, max_features=None, n_estimators=100, subsample=1; total time=   0.1s
# [CV] END learning_rate=0.001, max_depth=3, max_features=None, n_estimators=200, subsample=1; total time=   0.2s
# [CV] END learning_rate=0.001, max_depth=3, max_features=2, n_estimators=100, subsample=1; total time=   0.1s
# [CV] END learning_rate=0.001, max_depth=3, max_features=2, n_estimators=200, subsample=0.5; total time=   0.1s
# [CV] END learning_rate=0.001, max_depth=3, max_features=3, n_estimators=100, subsample=1; total time=   0.1s
# [CV] END learning_rate=0.001, max_depth=3, max_features=3, n_estimators=200, subsample=0.5; total time=   0.1s
# [CV] END learning_rate=0.001, max_depth=3, max_features=3, n_estimators=200, subsample=1; total time=   0.1s
# [CV] END learning_rate=0.001, max_depth=4, max_features=None, n_estimators=100, subsample=1; total time=   0.1s
# [CV] END learning_rate=0.001, max_depth=4, max_features=None, n_estimators=200, subsample=1; total time=   0.2s
# [CV] END learning_rate=0.001, max_depth=4, max_features=2, n_estimators=100, subsample=0.5; total time=   0.1s
# [CV] END learning_rate=0.001, max_depth=4, max_features=2, n_estimators=100, subsample=1; total time=   0.1s
# [CV] END learning_rate=0.001, max_depth=4, max_features=2, n_estimators=200, subsample=1; total time=   0.2s
# [CV] END learning_rate=0.001, max_depth=4, max_features=3, n_estimators=100, subsample=0.5; total time=   0.1s
# [CV] END learning_rate=0.001, max_depth=4, max_features=3, n_estimators=200, subsample=0.5; total time=   0.2s
# [CV] END learning_rate=0.001, max_depth=4, max_features=3, n_estimators=200, subsample=1; total time=   0.2s
# [CV] END learning_rate=0.001, max_depth=5, max_features=None, n_estimators=100, subsample=1; total time=   0.2s
# [CV] END learning_rate=0.001, max_depth=5, max_features=None, n_estimators=200, subsample=1; total time=   0.3s
# [CV] END learning_rate=0.001, max_depth=5, max_features=2, n_estimators=100, subsample=0.5; total time=   0.1s
# [CV] END learning_rate=0.001, max_depth=5, max_features=2, n_estimators=100, subsample=1; total time=   0.2s
# [CV] END learning_rate=0.001, max_depth=5, max_features=2, n_estimators=200, subsample=1; total time=   0.3s
# [CV] END learning_rate=0.001, max_depth=5, max_features=3, n_estimators=100, subsample=0.5; total time=   0.1s
# [CV] END learning_rate=0.001, max_depth=5, max_features=3, n_estimators=100, subsample=1; total time=   0.1s
# [CV] END learning_rate=0.001, max_depth=5, max_features=3, n_estimators=200, subsample=1; total time=   0.3s
# [CV] END learning_rate=0.01, max_depth=3, max_features=None, n_estimators=100, subsample=1; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=3, max_features=None, n_estimators=200, subsample=0.5; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=3, max_features=2, n_estimators=100, subsample=0.5; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=3, max_features=2, n_estimators=100, subsample=1; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=3, max_features=2, n_estimators=200, subsample=0.5; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=3, max_features=2, n_estimators=200, subsample=1; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=3, max_features=3, n_estimators=200, subsample=0.5; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=3, max_features=3, n_estimators=200, subsample=1; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=4, max_features=None, n_estimators=100, subsample=1; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=4, max_features=None, n_estimators=200, subsample=1; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=4, max_features=2, n_estimators=100, subsample=0.5; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=4, max_features=2, n_estimators=200, subsample=0.5; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=4, max_features=2, n_estimators=200, subsample=1; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=4, max_features=3, n_estimators=200, subsample=1; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=5, max_features=None, n_estimators=100, subsample=0.5; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=5, max_features=None, n_estimators=200, subsample=0.5; total time=   0.3s
# [CV] END learning_rate=0.01, max_depth=5, max_features=None, n_estimators=200, subsample=1; total time=   0.3s
# [CV] END learning_rate=0.01, max_depth=5, max_features=2, n_estimators=200, subsample=1; total time=   0.3s
# [CV] END learning_rate=0.01, max_depth=5, max_features=3, n_estimators=100, subsample=0.5; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=5, max_features=3, n_estimators=100, subsample=1; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=5, max_features=3, n_estimators=200, subsample=1; total time=   0.3s
# [CV] END learning_rate=0.001, max_depth=3, max_features=None, n_estimators=100, subsample=0.5; total time=   0.1s
# [CV] END learning_rate=0.001, max_depth=3, max_features=None, n_estimators=200, subsample=0.5; total time=   0.2s
# [CV] END learning_rate=0.001, max_depth=3, max_features=2, n_estimators=100, subsample=0.5; total time=   0.1s
# [CV] END learning_rate=0.001, max_depth=3, max_features=2, n_estimators=100, subsample=1; total time=   0.1s
# [CV] END learning_rate=0.001, max_depth=3, max_features=2, n_estimators=200, subsample=0.5; total time=   0.1s
# [CV] END learning_rate=0.001, max_depth=3, max_features=2, n_estimators=200, subsample=1; total time=   0.1s
# [CV] END learning_rate=0.001, max_depth=3, max_features=3, n_estimators=200, subsample=0.5; total time=   0.1s
# [CV] END learning_rate=0.001, max_depth=4, max_features=None, n_estimators=100, subsample=0.5; total time=   0.1s
# [CV] END learning_rate=0.001, max_depth=4, max_features=None, n_estimators=200, subsample=0.5; total time=   0.2s
# [CV] END learning_rate=0.001, max_depth=4, max_features=None, n_estimators=200, subsample=1; total time=   0.2s
# [CV] END learning_rate=0.001, max_depth=4, max_features=2, n_estimators=200, subsample=0.5; total time=   0.2s
# [CV] END learning_rate=0.001, max_depth=4, max_features=3, n_estimators=100, subsample=0.5; total time=   0.1s
# [CV] END learning_rate=0.001, max_depth=4, max_features=3, n_estimators=100, subsample=1; total time=   0.1s
# [CV] END learning_rate=0.001, max_depth=4, max_features=3, n_estimators=200, subsample=1; total time=   0.2s
# [CV] END learning_rate=0.001, max_depth=5, max_features=None, n_estimators=100, subsample=1; total time=   0.2s
# [CV] END learning_rate=0.001, max_depth=5, max_features=None, n_estimators=200, subsample=0.5; total time=   0.3s
# [CV] END learning_rate=0.001, max_depth=5, max_features=2, n_estimators=100, subsample=0.5; total time=   0.1s
# [CV] END learning_rate=0.001, max_depth=5, max_features=2, n_estimators=100, subsample=1; total time=   0.1s
# [CV] END learning_rate=0.001, max_depth=5, max_features=2, n_estimators=200, subsample=0.5; total time=   0.3s
# [CV] END learning_rate=0.001, max_depth=5, max_features=3, n_estimators=100, subsample=0.5; total time=   0.1s
# [CV] END learning_rate=0.001, max_depth=5, max_features=3, n_estimators=100, subsample=1; total time=   0.1s
# [CV] END learning_rate=0.001, max_depth=5, max_features=3, n_estimators=200, subsample=1; total time=   0.3s
# [CV] END learning_rate=0.01, max_depth=3, max_features=None, n_estimators=100, subsample=0.5; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=3, max_features=None, n_estimators=100, subsample=1; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=3, max_features=None, n_estimators=200, subsample=1; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=3, max_features=2, n_estimators=100, subsample=0.5; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=3, max_features=2, n_estimators=200, subsample=0.5; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=3, max_features=3, n_estimators=100, subsample=0.5; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=3, max_features=3, n_estimators=200, subsample=0.5; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=4, max_features=None, n_estimators=100, subsample=0.5; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=4, max_features=None, n_estimators=100, subsample=1; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=4, max_features=None, n_estimators=200, subsample=1; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=4, max_features=2, n_estimators=100, subsample=0.5; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=4, max_features=2, n_estimators=100, subsample=1; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=4, max_features=2, n_estimators=200, subsample=1; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=4, max_features=3, n_estimators=100, subsample=0.5; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=4, max_features=3, n_estimators=100, subsample=1; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=4, max_features=3, n_estimators=200, subsample=1; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=5, max_features=None, n_estimators=100, subsample=1; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=5, max_features=None, n_estimators=200, subsample=0.5; total time=   0.3s
# [CV] END learning_rate=0.01, max_depth=5, max_features=2, n_estimators=100, subsample=0.5; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=5, max_features=2, n_estimators=100, subsample=1; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=5, max_features=2, n_estimators=200, subsample=0.5; total time=   0.3s
# [CV] END learning_rate=0.01, max_depth=5, max_features=3, n_estimators=100, subsample=0.5; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=5, max_features=3, n_estimators=100, subsample=1; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=5, max_features=3, n_estimators=200, subsample=1; total time=   0.3s
# [CV] END learning_rate=0.001, max_depth=3, max_features=None, n_estimators=100, subsample=0.5; total time=   0.1s
# [CV] END learning_rate=0.001, max_depth=3, max_features=None, n_estimators=200, subsample=0.5; total time=   0.2s
# [CV] END learning_rate=0.001, max_depth=3, max_features=2, n_estimators=100, subsample=0.5; total time=   0.1s
# [CV] END learning_rate=0.001, max_depth=3, max_features=2, n_estimators=100, subsample=1; total time=   0.1s
# [CV] END learning_rate=0.001, max_depth=3, max_features=2, n_estimators=200, subsample=1; total time=   0.1s
# [CV] END learning_rate=0.001, max_depth=3, max_features=3, n_estimators=100, subsample=0.5; total time=   0.1s
# [CV] END learning_rate=0.001, max_depth=3, max_features=3, n_estimators=100, subsample=1; total time=   0.1s
# [CV] END learning_rate=0.001, max_depth=3, max_features=3, n_estimators=200, subsample=1; total time=   0.1s
# [CV] END learning_rate=0.001, max_depth=4, max_features=None, n_estimators=100, subsample=1; total time=   0.1s
# [CV] END learning_rate=0.001, max_depth=4, max_features=None, n_estimators=200, subsample=0.5; total time=   0.2s
# [CV] END learning_rate=0.001, max_depth=4, max_features=2, n_estimators=100, subsample=0.5; total time=   0.1s
# [CV] END learning_rate=0.001, max_depth=4, max_features=2, n_estimators=100, subsample=1; total time=   0.1s
# [CV] END learning_rate=0.001, max_depth=4, max_features=2, n_estimators=200, subsample=0.5; total time=   0.2s
# [CV] END learning_rate=0.001, max_depth=4, max_features=3, n_estimators=100, subsample=0.5; total time=   0.1s
# [CV] END learning_rate=0.001, max_depth=4, max_features=3, n_estimators=100, subsample=1; total time=   0.1s
# [CV] END learning_rate=0.001, max_depth=4, max_features=3, n_estimators=200, subsample=1; total time=   0.2s
# [CV] END learning_rate=0.001, max_depth=5, max_features=None, n_estimators=100, subsample=0.5; total time=   0.2s
# [CV] END learning_rate=0.001, max_depth=5, max_features=None, n_estimators=200, subsample=0.5; total time=   0.3s
# [CV] END learning_rate=0.001, max_depth=5, max_features=None, n_estimators=200, subsample=1; total time=   0.3s
# [CV] END learning_rate=0.001, max_depth=5, max_features=2, n_estimators=200, subsample=0.5; total time=   0.3s
# [CV] END learning_rate=0.001, max_depth=5, max_features=3, n_estimators=100, subsample=0.5; total time=   0.1s
# [CV] END learning_rate=0.001, max_depth=5, max_features=3, n_estimators=100, subsample=1; total time=   0.1s
# [CV] END learning_rate=0.001, max_depth=5, max_features=3, n_estimators=200, subsample=0.5; total time=   0.3s
# [CV] END learning_rate=0.01, max_depth=3, max_features=None, n_estimators=100, subsample=0.5; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=3, max_features=None, n_estimators=100, subsample=1; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=3, max_features=None, n_estimators=200, subsample=0.5; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=3, max_features=2, n_estimators=100, subsample=0.5; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=3, max_features=2, n_estimators=100, subsample=1; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=3, max_features=2, n_estimators=100, subsample=1; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=3, max_features=2, n_estimators=200, subsample=1; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=3, max_features=3, n_estimators=100, subsample=1; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=3, max_features=3, n_estimators=200, subsample=0.5; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=3, max_features=3, n_estimators=200, subsample=1; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=4, max_features=None, n_estimators=200, subsample=0.5; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=4, max_features=None, n_estimators=200, subsample=1; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=4, max_features=2, n_estimators=200, subsample=0.5; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=4, max_features=3, n_estimators=100, subsample=0.5; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=4, max_features=3, n_estimators=100, subsample=1; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=4, max_features=3, n_estimators=200, subsample=0.5; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=5, max_features=None, n_estimators=100, subsample=0.5; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=5, max_features=None, n_estimators=200, subsample=0.5; total time=   0.3s
# [CV] END learning_rate=0.01, max_depth=5, max_features=None, n_estimators=200, subsample=1; total time=   0.3s
# [CV] END learning_rate=0.01, max_depth=5, max_features=2, n_estimators=200, subsample=0.5; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=5, max_features=2, n_estimators=200, subsample=1; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=5, max_features=3, n_estimators=200, subsample=0.5; total time=   0.3s
# [CV] END learning_rate=0.01, max_depth=5, max_features=3, n_estimators=200, subsample=1; total time=   0.2s
# [CV] END learning_rate=0.001, max_depth=3, max_features=None, n_estimators=100, subsample=1; total time=   0.1s
# [CV] END learning_rate=0.001, max_depth=3, max_features=None, n_estimators=200, subsample=1; total time=   0.2s
# [CV] END learning_rate=0.001, max_depth=3, max_features=2, n_estimators=100, subsample=0.5; total time=   0.1s
# [CV] END learning_rate=0.001, max_depth=3, max_features=2, n_estimators=100, subsample=1; total time=   0.1s
# [CV] END learning_rate=0.001, max_depth=3, max_features=2, n_estimators=200, subsample=1; total time=   0.1s
# [CV] END learning_rate=0.001, max_depth=3, max_features=3, n_estimators=100, subsample=0.5; total time=   0.1s
# [CV] END learning_rate=0.001, max_depth=3, max_features=3, n_estimators=200, subsample=0.5; total time=   0.1s
# [CV] END learning_rate=0.001, max_depth=3, max_features=3, n_estimators=200, subsample=1; total time=   0.1s
# [CV] END learning_rate=0.001, max_depth=4, max_features=None, n_estimators=100, subsample=1; total time=   0.1s
# [CV] END learning_rate=0.001, max_depth=4, max_features=None, n_estimators=200, subsample=0.5; total time=   0.2s
# [CV] END learning_rate=0.001, max_depth=4, max_features=2, n_estimators=100, subsample=0.5; total time=   0.1s
# [CV] END learning_rate=0.001, max_depth=4, max_features=2, n_estimators=100, subsample=1; total time=   0.1s
# [CV] END learning_rate=0.001, max_depth=4, max_features=2, n_estimators=200, subsample=1; total time=   0.2s
# [CV] END learning_rate=0.001, max_depth=4, max_features=3, n_estimators=100, subsample=1; total time=   0.1s
# [CV] END learning_rate=0.001, max_depth=4, max_features=3, n_estimators=200, subsample=0.5; total time=   0.2s
# [CV] END learning_rate=0.001, max_depth=4, max_features=3, n_estimators=200, subsample=1; total time=   0.2s
# [CV] END learning_rate=0.001, max_depth=5, max_features=None, n_estimators=100, subsample=1; total time=   0.1s
# [CV] END learning_rate=0.001, max_depth=5, max_features=None, n_estimators=200, subsample=0.5; total time=   0.3s
# [CV] END learning_rate=0.001, max_depth=5, max_features=2, n_estimators=100, subsample=0.5; total time=   0.1s
# [CV] END learning_rate=0.001, max_depth=5, max_features=2, n_estimators=100, subsample=1; total time=   0.1s
# [CV] END learning_rate=0.001, max_depth=5, max_features=2, n_estimators=200, subsample=1; total time=   0.3s
# [CV] END learning_rate=0.001, max_depth=5, max_features=3, n_estimators=100, subsample=1; total time=   0.1s
# [CV] END learning_rate=0.001, max_depth=5, max_features=3, n_estimators=200, subsample=0.5; total time=   0.3s
# [CV] END learning_rate=0.001, max_depth=5, max_features=3, n_estimators=200, subsample=1; total time=   0.3s
# [CV] END learning_rate=0.01, max_depth=3, max_features=None, n_estimators=200, subsample=1; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=3, max_features=2, n_estimators=100, subsample=1; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=3, max_features=2, n_estimators=200, subsample=1; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=3, max_features=3, n_estimators=100, subsample=0.5; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=3, max_features=3, n_estimators=100, subsample=1; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=3, max_features=3, n_estimators=200, subsample=1; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=4, max_features=None, n_estimators=100, subsample=0.5; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=4, max_features=None, n_estimators=200, subsample=0.5; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=4, max_features=None, n_estimators=200, subsample=1; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=4, max_features=2, n_estimators=200, subsample=0.5; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=4, max_features=3, n_estimators=100, subsample=0.5; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=4, max_features=3, n_estimators=100, subsample=1; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=4, max_features=3, n_estimators=200, subsample=0.5; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=5, max_features=None, n_estimators=100, subsample=0.5; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=5, max_features=None, n_estimators=100, subsample=1; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=5, max_features=None, n_estimators=200, subsample=0.5; total time=   0.3s
# [CV] END learning_rate=0.01, max_depth=5, max_features=2, n_estimators=100, subsample=0.5; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=5, max_features=2, n_estimators=100, subsample=1; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=5, max_features=2, n_estimators=200, subsample=1; total time=   0.3s
# [CV] END learning_rate=0.01, max_depth=5, max_features=3, n_estimators=100, subsample=0.5; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=5, max_features=3, n_estimators=200, subsample=0.5; total time=   0.3s
# [CV] END learning_rate=0.01, max_depth=5, max_features=3, n_estimators=200, subsample=1; total time=   0.2s

# %% [markdown]
# # prediction

# %%
prediction=xgb.predict(X_test)
accuracy_score(y_test, prediction)
# Out:
# 0.8212290502793296

# %% [markdown]
# # Grid Search CV

# %%
param_grid = {"booster":['dart','gbtree'],"eta":[0.1,0.2],"n_estimators":[100,200],'max_depth':[3], "learning_rate": [0.1],
             "subsample":[0.5], "colsample_bytree":[0.5], 'reg_alpha':[0,1]}

xgb_model = XGBClassifier()
xgb_grid = GridSearchCV(xgb_model, param_grid, scoring = "accuracy", verbose=2, n_jobs = -1, 
                        return_train_score=True)
xgb_grid.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 16 candidates, totalling 80 fits
# GridSearchCV(estimator=XGBClassifier(base_score=None, booster=None,
#                                      callbacks=None, colsample_bylevel=None,
#                                      colsample_bynode=None,
#                                      colsample_bytree=None,
#                                      early_stopping_rounds=None,
#                                      enable_categorical=False, eval_metric=None,
#                                      feature_types=None, gamma=None,
#                                      gpu_id=None, grow_policy=None,
#                                      importance_type=None,
#                                      interaction_constraints=None,
#                                      learning_rate=None, max_b...
#                                      missing=nan, monotone_constraints=None,
#                                      n_estimators=100, n_jobs=None,
#                                      num_parallel_tree=None, predictor=None,
#                                      random_state=None, ...),
#              n_jobs=-1,
#              param_grid={'booster': ['dart', 'gbtree'],
#                          'colsample_bytree': [0.5], 'eta': [0.1, 0.2],
#                          'learning_rate': [0.1], 'max_depth': [3],
#                          'n_estimators': [100, 200], 'reg_alpha': [0, 1],
#                          'subsample': [0.5]},
#              return_train_score=True, scoring='accuracy', verbose=2)

# %%
xgb_grid.best_params_
# Out:
# {'booster': 'gbtree',
#  'colsample_bytree': 0.5,
#  'eta': 0.1,
#  'learning_rate': 0.1,
#  'max_depth': 3,
#  'n_estimators': 200,
#  'reg_alpha': 1,
#  'subsample': 0.5}

# %%
xgb_grid.best_score_
# Out:
# 0.8202698709740964

# %%
y_pred_test = xgb_grid.predict(X_test)
y_pred_train = xgb_grid.predict(X_train)

# %%
xgb_accuracy_test = accuracy_score(y_test, y_pred_test)
xgb_accuracy_train = accuracy_score(y_train, y_pred_train)

xgb_f1_test = f1_score(y_test, y_pred_test)
xgb_f1_train = f1_score(y_train, y_pred_train)

xgb_accuracy_test, xgb_accuracy_train, xgb_f1_test, xgb_f1_train
# Out:
# (0.8156424581005587,
#  0.8735955056179775,
#  0.7692307692307692,
#  0.8170731707317073)

# %%
y_pred = xgb_grid.predict(X_test)
ada_f1 = f1_score(y_test, y_pred)
ada_recall = recall_score(y_test, y_pred)
ada_auc = roc_auc_score(y_test, y_pred)
eval_metric(xgb_grid, X_train, y_train, X_test, y_test)
# Out:
# Test_Set
# [[91  8]
#  [25 55]]
#               precision    recall  f1-score   support
#
#            0       0.78      0.92      0.85        99
#            1       0.87      0.69      0.77        80
#
#     accuracy                           0.82       179
#    macro avg       0.83      0.80      0.81       179
# weighted avg       0.82      0.82      0.81       179
#
#
# Train_Set
# [[421  29]
#  [ 61 201]]
#               precision    recall  f1-score   support
#
#            0       0.87      0.94      0.90       450
#            1       0.87      0.77      0.82       262
#
#     accuracy                           0.87       712
#    macro avg       0.87      0.85      0.86       712
# weighted avg       0.87      0.87      0.87       712

# %% [markdown]
# # Prediction with Best Hyper Parameters

# %%
xgb_test=XGBClassifier(booster='dart',
 eta=0.1,
 colsample_bytree= 0.5,
 learning_rate= 0.1,
 max_depth= 3,
 n_estimators= 100,
 reg_alpha= 0,
 subsample= 0.5)
xgb_test.fit(X_train,y_train)
# Out:
# XGBClassifier(base_score=None, booster='dart', callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=0.5, early_stopping_rounds=None,
#               enable_categorical=False, eta=0.1, eval_metric=None,
#               feature_types=None, gamma=None, gpu_id=None, grow_policy=None,
#               importance_type=None, interaction_constraints=None,
#               learning_rate=0.1, max_bin=None, max_cat_threshold=None,
#               max_cat_to_onehot=None, max_delta_step=None, max_depth=3,
#               max_leaves=None, min_child_weight=None, missing=nan,
#               monotone_constraints=None, n_estimators=100, n_jobs=None,
#               num_parallel_tree=None, predictor=None, ...)

# %%
sub_pred3=xgb_test.predict(test)
accuracy_score(gender_submission.Survived.values, sub_pred3)
# Out:
# 0.9066985645933014

# %% [markdown]
# # Feature Importances

# %%
model = XGBClassifier(booster='gbtree',
 eta=0.1,
 colsample_bytree= 0.5,
 learning_rate= 0.1,
 max_depth= 3,
 n_estimators= 100,
 reg_alpha= 1,
 subsample= 0.5,
 random_state=101)

model.fit(X_train, y_train)

model.feature_importances_

feats = pd.DataFrame(index=X.columns, data=model.feature_importances_, columns=['xgb_importance'])
xgb_imp_feats = feats.sort_values("xgb_importance")
xgb_imp_feats
# Out:
#           xgb_importance
# Embarked        0.041909
# Parch           0.047904
# SibSp           0.052183
# Age             0.077096
# Fare            0.107118
# Pclass          0.172211
# Sex             0.501579

# %%
sns.barplot(data=xgb_imp_feats, x=xgb_imp_feats.index,y='xgb_importance')

plt.xticks(rotation=90);

# %% [markdown]
# # Evaluating ROC Curves

# %%
plot_roc_curve(xgb_grid, X_test, y_test);
# Out:
# [CV] END learning_rate=0.001, max_depth=3, max_features=None, n_estimators=100, subsample=1; total time=   0.1s
# [CV] END learning_rate=0.001, max_depth=3, max_features=None, n_estimators=200, subsample=0.5; total time=   0.2s
# [CV] END learning_rate=0.001, max_depth=3, max_features=2, n_estimators=100, subsample=0.5; total time=   0.1s
# [CV] END learning_rate=0.001, max_depth=3, max_features=2, n_estimators=100, subsample=1; total time=   0.1s
# [CV] END learning_rate=0.001, max_depth=3, max_features=2, n_estimators=200, subsample=0.5; total time=   0.1s
# [CV] END learning_rate=0.001, max_depth=3, max_features=3, n_estimators=100, subsample=0.5; total time=   0.1s
# [CV] END learning_rate=0.001, max_depth=3, max_features=3, n_estimators=100, subsample=1; total time=   0.1s
# [CV] END learning_rate=0.001, max_depth=3, max_features=3, n_estimators=200, subsample=1; total time=   0.1s
# [CV] END learning_rate=0.001, max_depth=4, max_features=None, n_estimators=100, subsample=0.5; total time=   0.1s
# [CV] END learning_rate=0.001, max_depth=4, max_features=None, n_estimators=200, subsample=0.5; total time=   0.2s
# [CV] END learning_rate=0.001, max_depth=4, max_features=2, n_estimators=100, subsample=0.5; total time=   0.1s
# [CV] END learning_rate=0.001, max_depth=4, max_features=2, n_estimators=100, subsample=1; total time=   0.1s
# [CV] END learning_rate=0.001, max_depth=4, max_features=2, n_estimators=200, subsample=0.5; total time=   0.2s
# [CV] END learning_rate=0.001, max_depth=4, max_features=2, n_estimators=200, subsample=1; total time=   0.2s
# [CV] END learning_rate=0.001, max_depth=4, max_features=3, n_estimators=200, subsample=0.5; total time=   0.2s
# [CV] END learning_rate=0.001, max_depth=5, max_features=None, n_estimators=100, subsample=0.5; total time=   0.2s
# [CV] END learning_rate=0.001, max_depth=5, max_features=None, n_estimators=200, subsample=0.5; total time=   0.3s
# [CV] END learning_rate=0.001, max_depth=5, max_features=2, n_estimators=100, subsample=0.5; total time=   0.1s
# [CV] END learning_rate=0.001, max_depth=5, max_features=2, n_estimators=100, subsample=1; total time=   0.1s
# [CV] END learning_rate=0.001, max_depth=5, max_features=2, n_estimators=200, subsample=0.5; total time=   0.3s
# [CV] END learning_rate=0.001, max_depth=5, max_features=2, n_estimators=200, subsample=1; total time=   0.3s
# [CV] END learning_rate=0.001, max_depth=5, max_features=3, n_estimators=200, subsample=0.5; total time=   0.3s
# [CV] END learning_rate=0.01, max_depth=3, max_features=None, n_estimators=100, subsample=0.5; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=3, max_features=None, n_estimators=100, subsample=1; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=3, max_features=None, n_estimators=200, subsample=0.5; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=3, max_features=2, n_estimators=100, subsample=0.5; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=3, max_features=2, n_estimators=100, subsample=1; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=3, max_features=2, n_estimators=200, subsample=0.5; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=3, max_features=3, n_estimators=100, subsample=0.5; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=3, max_features=3, n_estimators=100, subsample=1; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=3, max_features=3, n_estimators=200, subsample=1; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=4, max_features=None, n_estimators=100, subsample=0.5; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=4, max_features=None, n_estimators=200, subsample=0.5; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=4, max_features=2, n_estimators=100, subsample=0.5; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=4, max_features=2, n_estimators=100, subsample=1; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=4, max_features=2, n_estimators=200, subsample=0.5; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=4, max_features=3, n_estimators=100, subsample=0.5; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=4, max_features=3, n_estimators=200, subsample=0.5; total time=   0.3s
# [CV] END learning_rate=0.01, max_depth=5, max_features=None, n_estimators=100, subsample=0.5; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=5, max_features=None, n_estimators=200, subsample=0.5; total time=   0.3s
# [CV] END learning_rate=0.01, max_depth=5, max_features=2, n_estimators=100, subsample=0.5; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=5, max_features=2, n_estimators=100, subsample=1; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=5, max_features=2, n_estimators=200, subsample=0.5; total time=   0.3s
# [CV] END learning_rate=0.01, max_depth=5, max_features=3, n_estimators=100, subsample=0.5; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=5, max_features=3, n_estimators=100, subsample=1; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=5, max_features=3, n_estimators=200, subsample=1; total time=   0.3s
# [CV] END booster=dart, colsample_bytree=0.5, eta=0.1, learning_rate=0.1, max_depth=3, n_estimators=100, reg_alpha=0, subsample=0.5; total time=   0.2s
# [CV] END booster=dart, colsample_bytree=0.5, eta=0.1, learning_rate=0.1, max_depth=3, n_estimators=100, reg_alpha=0, subsample=0.5; total time=   0.2s
# [CV] END booster=dart, colsample_bytree=0.5, eta=0.1, learning_rate=0.1, max_depth=3, n_estimators=100, reg_alpha=1, subsample=0.5; total time=   0.2s
# [CV] END booster=dart, colsample_bytree=0.5, eta=0.1, learning_rate=0.1, max_depth=3, n_estimators=200, reg_alpha=0, subsample=0.5; total time=   0.7s
# [CV] END booster=dart, colsample_bytree=0.5, eta=0.1, learning_rate=0.1, max_depth=3, n_estimators=200, reg_alpha=0, subsample=0.5; total time=   0.7s
# [CV] END booster=dart, colsample_bytree=0.5, eta=0.1, learning_rate=0.1, max_depth=3, n_estimators=200, reg_alpha=1, subsample=0.5; total time=   0.7s
# [CV] END booster=dart, colsample_bytree=0.5, eta=0.2, learning_rate=0.1, max_depth=3, n_estimators=200, reg_alpha=1, subsample=0.5; total time=   0.7s
# [CV] END booster=gbtree, colsample_bytree=0.5, eta=0.1, learning_rate=0.1, max_depth=3, n_estimators=200, reg_alpha=1, subsample=0.5; total time=   0.1s
# [CV] END booster=gbtree, colsample_bytree=0.5, eta=0.2, learning_rate=0.1, max_depth=3, n_estimators=100, reg_alpha=0, subsample=0.5; total time=   0.0s
# [CV] END booster=gbtree, colsample_bytree=0.5, eta=0.2, learning_rate=0.1, max_depth=3, n_estimators=100, reg_alpha=1, subsample=0.5; total time=   0.0s
# [CV] END booster=gbtree, colsample_bytree=0.5, eta=0.2, learning_rate=0.1, max_depth=3, n_estimators=200, reg_alpha=0, subsample=0.5; total time=   0.1s
# [CV] END booster=dart, colsample_bytree=0.5, eta=0.1, learning_rate=0.1, max_depth=3, n_estimators=100, reg_alpha=0, subsample=0.5; total time=   0.2s
# [CV] END booster=dart, colsample_bytree=0.5, eta=0.1, learning_rate=0.1, max_depth=3, n_estimators=200, reg_alpha=0, subsample=0.5; total time=   0.7s
# [CV] END booster=dart, colsample_bytree=0.5, eta=0.2, learning_rate=0.1, max_depth=3, n_estimators=100, reg_alpha=0, subsample=0.5; total time=   0.2s
# [CV] END booster=dart, colsample_bytree=0.5, eta=0.2, learning_rate=0.1, max_depth=3, n_estimators=100, reg_alpha=1, subsample=0.5; total time=   0.2s
# [CV] END booster=dart, colsample_bytree=0.5, eta=0.2, learning_rate=0.1, max_depth=3, n_estimators=200, reg_alpha=1, subsample=0.5; total time=   0.7s
# [CV] END booster=gbtree, colsample_bytree=0.5, eta=0.1, learning_rate=0.1, max_depth=3, n_estimators=200, reg_alpha=0, subsample=0.5; total time=   0.1s
# [CV] END booster=gbtree, colsample_bytree=0.5, eta=0.2, learning_rate=0.1, max_depth=3, n_estimators=100, reg_alpha=0, subsample=0.5; total time=   0.0s
# [CV] END booster=gbtree, colsample_bytree=0.5, eta=0.2, learning_rate=0.1, max_depth=3, n_estimators=100, reg_alpha=0, subsample=0.5; total time=   0.0s
# [CV] END booster=gbtree, colsample_bytree=0.5, eta=0.2, learning_rate=0.1, max_depth=3, n_estimators=100, reg_alpha=1, subsample=0.5; total time=   0.1s
# [CV] END booster=gbtree, colsample_bytree=0.5, eta=0.2, learning_rate=0.1, max_depth=3, n_estimators=200, reg_alpha=1, subsample=0.5; total time=   0.1s
# [CV] END booster=dart, colsample_bytree=0.5, eta=0.1, learning_rate=0.1, max_depth=3, n_estimators=100, reg_alpha=0, subsample=0.5; total time=   0.2s
# [CV] END booster=dart, colsample_bytree=0.5, eta=0.1, learning_rate=0.1, max_depth=3, n_estimators=200, reg_alpha=0, subsample=0.5; total time=   0.7s
# [CV] END booster=dart, colsample_bytree=0.5, eta=0.2, learning_rate=0.1, max_depth=3, n_estimators=100, reg_alpha=0, subsample=0.5; total time=   0.2s
# [CV] END booster=dart, colsample_bytree=0.5, eta=0.2, learning_rate=0.1, max_depth=3, n_estimators=100, reg_alpha=1, subsample=0.5; total time=   0.2s
# [CV] END booster=dart, colsample_bytree=0.5, eta=0.2, learning_rate=0.1, max_depth=3, n_estimators=200, reg_alpha=0, subsample=0.5; total time=   0.7s
# [CV] END booster=gbtree, colsample_bytree=0.5, eta=0.1, learning_rate=0.1, max_depth=3, n_estimators=100, reg_alpha=0, subsample=0.5; total time=   0.0s
# [CV] END booster=gbtree, colsample_bytree=0.5, eta=0.1, learning_rate=0.1, max_depth=3, n_estimators=100, reg_alpha=1, subsample=0.5; total time=   0.0s
# [CV] END booster=gbtree, colsample_bytree=0.5, eta=0.1, learning_rate=0.1, max_depth=3, n_estimators=200, reg_alpha=0, subsample=0.5; total time=   0.1s
# [CV] END booster=gbtree, colsample_bytree=0.5, eta=0.1, learning_rate=0.1, max_depth=3, n_estimators=200, reg_alpha=1, subsample=0.5; total time=   0.1s
# [CV] END booster=gbtree, colsample_bytree=0.5, eta=0.2, learning_rate=0.1, max_depth=3, n_estimators=100, reg_alpha=0, subsample=0.5; total time=   0.0s
# [CV] END booster=gbtree, colsample_bytree=0.5, eta=0.2, learning_rate=0.1, max_depth=3, n_estimators=200, reg_alpha=0, subsample=0.5; total time=   0.1s
# [CV] END booster=gbtree, colsample_bytree=0.5, eta=0.2, learning_rate=0.1, max_depth=3, n_estimators=200, reg_alpha=1, subsample=0.5; total time=   0.1s
# [CV] END booster=dart, colsample_bytree=0.5, eta=0.1, learning_rate=0.1, max_depth=3, n_estimators=100, reg_alpha=0, subsample=0.5; total time=   0.2s
# [CV] END booster=dart, colsample_bytree=0.5, eta=0.1, learning_rate=0.1, max_depth=3, n_estimators=200, reg_alpha=1, subsample=0.5; total time=   0.7s
# [CV] END booster=dart, colsample_bytree=0.5, eta=0.2, learning_rate=0.1, max_depth=3, n_estimators=100, reg_alpha=1, subsample=0.5; total time=   0.2s
# [CV] END booster=dart, colsample_bytree=0.5, eta=0.2, learning_rate=0.1, max_depth=3, n_estimators=200, reg_alpha=0, subsample=0.5; total time=   0.7s
# [CV] END booster=gbtree, colsample_bytree=0.5, eta=0.1, learning_rate=0.1, max_depth=3, n_estimators=100, reg_alpha=0, subsample=0.5; total time=   0.0s
# [CV] END booster=gbtree, colsample_bytree=0.5, eta=0.1, learning_rate=0.1, max_depth=3, n_estimators=100, reg_alpha=0, subsample=0.5; total time=   0.0s
# [CV] END booster=gbtree, colsample_bytree=0.5, eta=0.1, learning_rate=0.1, max_depth=3, n_estimators=100, reg_alpha=1, subsample=0.5; total time=   0.0s
# [CV] END booster=gbtree, colsample_bytree=0.5, eta=0.1, learning_rate=0.1, max_depth=3, n_estimators=100, reg_alpha=1, subsample=0.5; total time=   0.0s
# [CV] END booster=gbtree, colsample_bytree=0.5, eta=0.1, learning_rate=0.1, max_depth=3, n_estimators=200, reg_alpha=0, subsample=0.5; total time=   0.1s
# [CV] END booster=gbtree, colsample_bytree=0.5, eta=0.1, learning_rate=0.1, max_depth=3, n_estimators=200, reg_alpha=1, subsample=0.5; total time=   0.1s
# [CV] END booster=gbtree, colsample_bytree=0.5, eta=0.2, learning_rate=0.1, max_depth=3, n_estimators=100, reg_alpha=1, subsample=0.5; total time=   0.0s
# [CV] END booster=gbtree, colsample_bytree=0.5, eta=0.2, learning_rate=0.1, max_depth=3, n_estimators=200, reg_alpha=0, subsample=0.5; total time=   0.1s
# [CV] END booster=gbtree, colsample_bytree=0.5, eta=0.2, learning_rate=0.1, max_depth=3, n_estimators=200, reg_alpha=1, subsample=0.5; total time=   0.1s
# [CV] END booster=dart, colsample_bytree=0.5, eta=0.1, learning_rate=0.1, max_depth=3, n_estimators=100, reg_alpha=1, subsample=0.5; total time=   0.2s
# [CV] END booster=dart, colsample_bytree=0.5, eta=0.1, learning_rate=0.1, max_depth=3, n_estimators=200, reg_alpha=1, subsample=0.5; total time=   0.7s
# [CV] END booster=dart, colsample_bytree=0.5, eta=0.2, learning_rate=0.1, max_depth=3, n_estimators=100, reg_alpha=0, subsample=0.5; total time=   0.2s
# [CV] END booster=dart, colsample_bytree=0.5, eta=0.2, learning_rate=0.1, max_depth=3, n_estimators=200, reg_alpha=0, subsample=0.5; total time=   0.7s
# [CV] END booster=gbtree, colsample_bytree=0.5, eta=0.1, learning_rate=0.1, max_depth=3, n_estimators=100, reg_alpha=0, subsample=0.5; total time=   0.0s
# [CV] END booster=gbtree, colsample_bytree=0.5, eta=0.1, learning_rate=0.1, max_depth=3, n_estimators=100, reg_alpha=0, subsample=0.5; total time=   0.1s
# [CV] END booster=gbtree, colsample_bytree=0.5, eta=0.1, learning_rate=0.1, max_depth=3, n_estimators=100, reg_alpha=1, subsample=0.5; total time=   0.0s
# [CV] END booster=gbtree, colsample_bytree=0.5, eta=0.1, learning_rate=0.1, max_depth=3, n_estimators=200, reg_alpha=0, subsample=0.5; total time=   0.1s
# [CV] END booster=gbtree, colsample_bytree=0.5, eta=0.1, learning_rate=0.1, max_depth=3, n_estimators=200, reg_alpha=1, subsample=0.5; total time=   0.1s
# [CV] END booster=gbtree, colsample_bytree=0.5, eta=0.2, learning_rate=0.1, max_depth=3, n_estimators=100, reg_alpha=0, subsample=0.5; total time=   0.0s
# [CV] END booster=gbtree, colsample_bytree=0.5, eta=0.2, learning_rate=0.1, max_depth=3, n_estimators=100, reg_alpha=1, subsample=0.5; total time=   0.0s
# [CV] END booster=gbtree, colsample_bytree=0.5, eta=0.2, learning_rate=0.1, max_depth=3, n_estimators=200, reg_alpha=0, subsample=0.5; total time=   0.1s
# [CV] END booster=gbtree, colsample_bytree=0.5, eta=0.2, learning_rate=0.1, max_depth=3, n_estimators=200, reg_alpha=1, subsample=0.5; total time=   0.1s
# [CV] END booster=dart, colsample_bytree=0.5, eta=0.1, learning_rate=0.1, max_depth=3, n_estimators=100, reg_alpha=1, subsample=0.5; total time=   0.2s
# [CV] END booster=dart, colsample_bytree=0.5, eta=0.1, learning_rate=0.1, max_depth=3, n_estimators=200, reg_alpha=0, subsample=0.5; total time=   0.7s
# [CV] END booster=dart, colsample_bytree=0.5, eta=0.2, learning_rate=0.1, max_depth=3, n_estimators=100, reg_alpha=0, subsample=0.5; total time=   0.2s
# [CV] END booster=dart, colsample_bytree=0.5, eta=0.2, learning_rate=0.1, max_depth=3, n_estimators=100, reg_alpha=1, subsample=0.5; total time=   0.2s
# [CV] END booster=dart, colsample_bytree=0.5, eta=0.2, learning_rate=0.1, max_depth=3, n_estimators=200, reg_alpha=1, subsample=0.5; total time=   0.7s
# [CV] END booster=gbtree, colsample_bytree=0.5, eta=0.1, learning_rate=0.1, max_depth=3, n_estimators=100, reg_alpha=1, subsample=0.5; total time=   0.1s
# [CV] END booster=gbtree, colsample_bytree=0.5, eta=0.1, learning_rate=0.1, max_depth=3, n_estimators=200, reg_alpha=0, subsample=0.5; total time=   0.1s
# [CV] END booster=gbtree, colsample_bytree=0.5, eta=0.1, learning_rate=0.1, max_depth=3, n_estimators=200, reg_alpha=1, subsample=0.5; total time=   0.1s
# [CV] END booster=gbtree, colsample_bytree=0.5, eta=0.2, learning_rate=0.1, max_depth=3, n_estimators=100, reg_alpha=1, subsample=0.5; total time=   0.0s
# [CV] END booster=gbtree, colsample_bytree=0.5, eta=0.2, learning_rate=0.1, max_depth=3, n_estimators=200, reg_alpha=0, subsample=0.5; total time=   0.1s
# [CV] END booster=gbtree, colsample_bytree=0.5, eta=0.2, learning_rate=0.1, max_depth=3, n_estimators=200, reg_alpha=1, subsample=0.5; total time=   0.1s
# [CV] END booster=dart, colsample_bytree=0.5, eta=0.1, learning_rate=0.1, max_depth=3, n_estimators=100, reg_alpha=1, subsample=0.5; total time=   0.2s
# [CV] END booster=dart, colsample_bytree=0.5, eta=0.1, learning_rate=0.1, max_depth=3, n_estimators=200, reg_alpha=1, subsample=0.5; total time=   0.7s
# [CV] END booster=dart, colsample_bytree=0.5, eta=0.2, learning_rate=0.1, max_depth=3, n_estimators=100, reg_alpha=1, subsample=0.5; total time=   0.2s
# [CV] END booster=dart, colsample_bytree=0.5, eta=0.2, learning_rate=0.1, max_depth=3, n_estimators=200, reg_alpha=0, subsample=0.5; total time=   0.7s
# [CV] END booster=dart, colsample_bytree=0.5, eta=0.2, learning_rate=0.1, max_depth=3, n_estimators=200, reg_alpha=1, subsample=0.5; total time=   0.6s
# [CV] END booster=dart, colsample_bytree=0.5, eta=0.1, learning_rate=0.1, max_depth=3, n_estimators=100, reg_alpha=1, subsample=0.5; total time=   0.2s
# [CV] END booster=dart, colsample_bytree=0.5, eta=0.1, learning_rate=0.1, max_depth=3, n_estimators=200, reg_alpha=1, subsample=0.5; total time=   0.7s
# [CV] END booster=dart, colsample_bytree=0.5, eta=0.2, learning_rate=0.1, max_depth=3, n_estimators=100, reg_alpha=0, subsample=0.5; total time=   0.2s
# [CV] END booster=dart, colsample_bytree=0.5, eta=0.2, learning_rate=0.1, max_depth=3, n_estimators=200, reg_alpha=0, subsample=0.5; total time=   0.7s
# [CV] END booster=dart, colsample_bytree=0.5, eta=0.2, learning_rate=0.1, max_depth=3, n_estimators=200, reg_alpha=1, subsample=0.5; total time=   0.6s

# %%
xgb_auc = roc_auc_score(y_test, y_pred_test)
xgb_auc
# Out:
# 0.8033459595959597

# %%
plot_precision_recall_curve(xgb_grid, X_test, y_test);

# %%
y_pred_proba = xgb_grid.predict_proba(X_test)[:, 1]

precision, recall, threshold = precision_recall_curve(y_test, y_pred_proba)

xgb_prc = auc(recall, precision)
xgb_prc
# Out:
# 0.902983864565539

# %% [markdown]
# # Compare the Feature Importances

# %%
pd.concat([ada_imp_feats, grad_imp_feats, xgb_imp_feats], axis=1)
# Out:
#           ada_importance  grad_importance  xgb_importance
# Embarked           0.035         0.023792        0.041909
# Parch              0.040         0.026482        0.047904
# Pclass             0.055         0.165611        0.172211
# SibSp              0.085         0.042335        0.052183
# Sex                0.100         0.501990        0.501579
# Age                0.280         0.105593        0.077096
# Fare               0.405         0.134197        0.107118

# %% [markdown]
# # Compare the Models

# %%
compare = pd.DataFrame({"Model": ["AdaBoost", "GradientBoost", "XGBoost"],
                        "Accuracy": [ada_accuracy_test, grb_accuracy_test, xgb_accuracy_test],
                        "F1": [ada_f1_test, grb_f1_test, xgb_f1_test],
                        "ROC_AUC": [ada_auc, grb_auc, xgb_auc],
                        "PRC": [ada_prc, grb_prc, xgb_prc]})

def labels(ax):
    for p in ax.patches:
        width = p.get_width()                        # get bar length
        ax.text(width,                               # set the text at 1 unit right of the bar
                p.get_y() + p.get_height() / 2,      # get Y coordinate + X coordinate / 2
                '{:1.3f}'.format(width),             # set variable to display, 2 decimals
                ha = 'left',                         # horizontal alignment
                va = 'center')                       # vertical alignment
    
plt.figure(figsize=(16,16))

plt.subplot(411)
compare = compare.sort_values(by="F1", ascending=False)
ax=sns.barplot(x="F1", y="Model", data=compare, palette="Blues_d")
labels(ax)

plt.subplot(412)
compare = compare.sort_values(by="Accuracy", ascending=False)
ax=sns.barplot(x="Accuracy", y="Model", data=compare, palette="Blues_d")
labels(ax)

plt.subplot(413)
compare = compare.sort_values(by="ROC_AUC", ascending=False)
ax=sns.barplot(x="ROC_AUC", y="Model", data=compare, palette="Blues_d")
labels(ax)

plt.subplot(414)
compare = compare.sort_values(by="PRC", ascending=False)
ax=sns.barplot(x="PRC", y="Model", data=compare, palette="Blues_d")
labels(ax)

plt.show()

# %%
train["Survived"].value_counts()
# Out:
# 0    549
# 1    342
# Name: Survived, dtype: int64

# %% [markdown]
# # Summary
#
# My goal was to predict who died or survived in the Titanic disaster using ADABOOST, GRADIENTBOOST, XGBOOST machine learning models. After trying models, I evaluated them using different metrics including F1 score, accuracy, ROC AUC, and precision-recall curve. Based on the evaluation results, I have chosen the XGBoost model as the best model for my prediction task. It achieved the highest F1 score of 0.769, as well as high accuracy and ROC AUC scores of 0.816 and 0.803, respectively. The precision-recall curve values were also strong, with a precision of 0.903. Overall, the XGBoost model provides the most accurate and reliable predictions of who perished in the Titanic disaster.
